# %% [markdown]
# # Импорты

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import requests

import backtrader as bt
from dateutil.relativedelta import relativedelta

# %% [markdown]
# # Датафид

# %%
class PandasOHLCV(bt.feeds.PandasData):
    """
    Требуемые колонки в DataFrame:
    open, high, low, close, volume
    Индекс: datetime
    """
    params = (
        ("datetime", None),
        ("open", "open"),
        ("high", "high"),
        ("low", "low"),
        ("close", "close"),
        ("volume", "volume"),
        ("openinterest", -1),
    )

# %% [markdown]
# # Кастомные индикаторы

# %%
class VolumeRatio(bt.Indicator):
    lines = ("ratio",)
    params = (("period", 20),)

    def __init__(self):
        vol_ma = bt.indicators.SimpleMovingAverage(self.data.volume, period=self.p.period)
        self.lines.ratio = self.data.volume / vol_ma


class PullbackPct(bt.Indicator):
    lines = ("pullback_pct",)
    params = (("lookback", 10),)

    def __init__(self):
        hh = bt.indicators.Highest(self.data.high(-1), period=self.p.lookback)
        self.lines.pullback_pct = (hh - self.data.close) / hh


class EMASlope(bt.Indicator):
    lines = ("slope",)
    params = (("period", 10),)

    def __init__(self):
        self.lines.slope = self.data - self.data(-self.p.period)

# %% [markdown]
# # Analyzer для списка сделок

# %%
class TradeListAnalyzer(bt.Analyzer):
    def start(self):
        self.trades = []

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        dt_open = bt.num2date(trade.dtopen)
        dt_close = bt.num2date(trade.dtclose)

        price_out = trade.price + (trade.pnl / trade.size if trade.size else 0.0)

        self.trades.append({
            "entry_time": pd.Timestamp(dt_open),
            "exit_time": pd.Timestamp(dt_close),
            "size": trade.size,
            "price_in": trade.price,
            "price_out": price_out,
            "pnl_gross": trade.pnl,
            "pnl_net": trade.pnlcomm,
            "barlen": trade.barlen,
        })

    def get_analysis(self):
        return self.trades

# %% [markdown]
# # Стратегия BTC trend

# %%
class BTCTrendPullbackStrategy(bt.Strategy):
    params = dict(
        ema_fast=20,
        ema_slow=200,
        atr_period=14,
        volume_window=20,
        swing_window=10,
        slope_lookback=10,

        pullback_min_pct=0.003,
        pullback_max_pct=0.03,
        max_close_above_fast_ema_pct=0.01,
        min_volume_ratio=1.0,
        min_atr_pct=0.002,
        max_atr_pct=0.08,
        use_breakout_trigger=True,

        risk_per_trade=0.01,
        rr_target=2.0,
        atr_stop_mult=1.5,
        max_bars_in_trade=100,

        debug=False,
    )

    def log(self, txt):
        if self.p.debug:
            dt = self.datas[0].datetime.datetime(0)
            print(f"{dt} | {txt}")

    def __init__(self):
        data = self.datas[0]

        self.order = None
        self.entry_bar = None
        self.entry_price = None
        self.stop_price = None
        self.take_price = None

        self.ema_fast = bt.indicators.EMA(data.close, period=self.p.ema_fast)
        self.ema_slow = bt.indicators.EMA(data.close, period=self.p.ema_slow)
        self.ema_slow_slope = EMASlope(self.ema_slow, period=self.p.slope_lookback)

        self.atr = bt.indicators.ATR(data, period=self.p.atr_period)
        self.atr_pct = self.atr / data.close

        self.volume_ratio = VolumeRatio(data, period=self.p.volume_window)
        self.pullback_pct = PullbackPct(data, lookback=self.p.swing_window)

        self.recent_low = bt.indicators.Lowest(data.low(-1), period=self.p.swing_window)
        micro_window = max(3, self.p.swing_window // 2)
        self.micro_high = bt.indicators.Highest(data.high(-1), period=micro_window)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status == order.Completed:
            if order.isbuy():
                self.log(f"BUY EXECUTED | price={order.executed.price:.2f}, size={order.executed.size:.6f}")
            elif order.issell():
                self.log(f"SELL EXECUTED | price={order.executed.price:.2f}, size={order.executed.size:.6f}")

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log(f"ORDER FAILED | status={order.getstatusname()}")

        self.order = None

    def notify_trade(self, trade):
        if trade.isclosed:
            self.log(f"TRADE CLOSED | gross={trade.pnl:.2f}, net={trade.pnlcomm:.2f}")

    def _long_signal(self):
        close = self.data.close[0]

        trend_up = (close > self.ema_slow[0]) and (self.ema_slow_slope[0] > 0)

        pullback_ok = (
            (self.pullback_pct[0] >= self.p.pullback_min_pct) and
            (self.pullback_pct[0] <= self.p.pullback_max_pct) and
            (close >= self.ema_fast[0] * (1 - self.p.max_close_above_fast_ema_pct))
        )

        volatility_ok = (
            (self.atr_pct[0] >= self.p.min_atr_pct) and
            (self.atr_pct[0] <= self.p.max_atr_pct)
        )

        volume_ok = self.volume_ratio[0] >= self.p.min_volume_ratio

        if self.p.use_breakout_trigger:
            trigger_long = close > self.micro_high[0]
        else:
            trigger_long = (close > self.ema_fast[0]) and (self.data.close[-1] <= self.ema_fast[-1])

        return trend_up and pullback_ok and volatility_ok and volume_ok and trigger_long

    def _calc_position_size(self, entry_price, stop_price):
        cash = self.broker.getcash()
        risk_amount = cash * self.p.risk_per_trade
        stop_distance = entry_price - stop_price

        if stop_distance <= 0:
            return 0.0

        size = risk_amount / stop_distance
        max_affordable = cash / entry_price if entry_price > 0 else 0.0
        size = min(size, max_affordable)

        if not np.isfinite(size) or size <= 0:
            return 0.0

        return size

    def next(self):
        if self.order:
            return

        close = self.data.close[0]

        if self.position:
            bars_held = len(self) - self.entry_bar if self.entry_bar is not None else 0

            if self.data.low[0] <= self.stop_price:
                self.log(f"EXIT STOP | stop={self.stop_price:.2f}")
                self.order = self.close()
                return

            if self.data.high[0] >= self.take_price:
                self.log(f"EXIT TAKE | take={self.take_price:.2f}")
                self.order = self.close()
                return

            if bars_held >= self.p.max_bars_in_trade:
                self.log("EXIT TIMEOUT")
                self.order = self.close()
                return

        if not self.position:
            if self._long_signal():
                entry_price = close
                atr_stop = entry_price - self.p.atr_stop_mult * self.atr[0]
                structural_stop = self.recent_low[0]
                stop_price = min(structural_stop, atr_stop)

                if not np.isfinite(stop_price) or stop_price >= entry_price:
                    return

                size = self._calc_position_size(entry_price, stop_price)
                if size <= 0:
                    return

                take_price = entry_price + self.p.rr_target * (entry_price - stop_price)

                self.entry_price = entry_price
                self.stop_price = stop_price
                self.take_price = take_price
                self.entry_bar = len(self)

                self.log(
                    f"ENTRY LONG | entry={entry_price:.2f}, stop={stop_price:.2f}, "
                    f"take={take_price:.2f}, size={size:.6f}"
                )
                self.order = self.buy(size=size)

# %% [markdown]
# # Функция одиночного прогона бэктеста

# %%
def run_backtest_bt(
    df: pd.DataFrame,
    strategy_cls=BTCTrendPullbackStrategy,
    strategy_params=None,
    initial_cash=10_000.0,
    commission=0.0004,
    slippage_perc=0.0002,
    plot=False,
):
    if strategy_params is None:
        strategy_params = {}

    data = df.copy()
    required_cols = {"open", "high", "low", "close", "volume"}
    missing = required_cols - set(data.columns)
    if missing:
        raise ValueError(f"Missing required columns: {missing}")

    if not isinstance(data.index, pd.DatetimeIndex):
        raise ValueError("DataFrame index must be DatetimeIndex")

    data = data.sort_index()

    cerebro = bt.Cerebro(stdstats=False)
    cerebro.broker.setcash(initial_cash)
    cerebro.broker.setcommission(commission=commission)
    cerebro.broker.set_slippage_perc(perc=slippage_perc)

    feed = PandasOHLCV(dataname=data)
    cerebro.adddata(feed)

    cerebro.addstrategy(strategy_cls, **strategy_params)

    cerebro.addanalyzer(bt.analyzers.TimeReturn, _name="timereturn")
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name="drawdown")
    cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name="tradeanalyzer")
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name="sharpe", timeframe=bt.TimeFrame.Days, annualize=True)
    cerebro.addanalyzer(TradeListAnalyzer, _name="tradelist")

    results = cerebro.run()
    strat = results[0]

    final_value = cerebro.broker.getvalue()
    pnl = final_value - initial_cash

    # -------- helper ----------
    def safe_float(x, default=0.0):
        if x is None:
            return float(default)
        try:
            x = float(x)
        except (TypeError, ValueError):
            return float(default)
        if not np.isfinite(x):
            return float(default)
        return x

    # Equity curve
    rets = strat.analyzers.timereturn.get_analysis()
    returns_series = pd.Series(rets, dtype=float)
    if len(returns_series) > 0:
        equity_curve = (1 + returns_series).cumprod() * initial_cash
        equity_df = pd.DataFrame({"equity": equity_curve})
        equity_df.index = pd.to_datetime(equity_df.index)
    else:
        equity_df = pd.DataFrame(columns=["equity"])

    # Trades
    trades = strat.analyzers.tradelist.get_analysis()
    trades_df = pd.DataFrame(trades) if trades else pd.DataFrame()

    trade_an = strat.analyzers.tradeanalyzer.get_analysis()
    dd_an = strat.analyzers.drawdown.get_analysis()
    sharpe_an = strat.analyzers.sharpe.get_analysis()

    total_trades = trade_an.get("total", {}).get("closed", 0) if isinstance(trade_an, dict) else 0
    won_total = trade_an.get("won", {}).get("total", 0) if isinstance(trade_an, dict) else 0

    gross_profit = trade_an.get("won", {}).get("pnl", {}).get("total", 0.0) if isinstance(trade_an, dict) else 0.0
    gross_loss_abs = abs(trade_an.get("lost", {}).get("pnl", {}).get("total", 0.0)) if isinstance(trade_an, dict) else 0.0
    profit_factor = gross_profit / gross_loss_abs if gross_loss_abs > 0 else np.nan

    sharpe_value = sharpe_an.get("sharperatio", 0.0) if isinstance(sharpe_an, dict) else 0.0
    max_dd_value = dd_an.get("max", {}).get("drawdown", 0.0) if isinstance(dd_an, dict) else 0.0

    metrics = {
        "initial_cash": safe_float(initial_cash),
        "final_value": safe_float(final_value),
        "net_profit": safe_float(pnl),
        "total_return_pct": safe_float((final_value / initial_cash - 1) * 100),
        "max_drawdown_pct": safe_float(max_dd_value),
        "n_trades": int(total_trades),
        "win_rate_pct": safe_float((won_total / total_trades) * 100 if total_trades > 0 else 0.0),
        "profit_factor": safe_float(profit_factor, default=0.0),
        "sharpe": safe_float(sharpe_value, default=0.0),
    }

    if plot:
        cerebro.plot(style="candlestick")

    return {
        "metrics": metrics,
        "trades_df": trades_df,
        "equity_df": equity_df,
        "strategy": strat,
        "cerebro": cerebro,
    }

# %% [markdown]
# # Дефолтные параметры стратегии

# %%
DEFAULT_PARAMS = dict(
    ema_fast=20,
    ema_slow=200,
    atr_period=14,
    volume_window=20,
    swing_window=10,
    slope_lookback=10,
    pullback_min_pct=0.003,
    pullback_max_pct=0.03,
    max_close_above_fast_ema_pct=0.01,
    min_volume_ratio=1.0,
    min_atr_pct=0.002,
    max_atr_pct=0.08,
    use_breakout_trigger=True,
    risk_per_trade=0.01,
    rr_target=2.0,
    atr_stop_mult=1.5,
    max_bars_in_trade=100,
    debug=False,
)

# %% [markdown]
# # Загрузка и подготовка данных

# %%
def load_binance_klines(
    symbol: str = "BTCUSDT",
    interval: str = "5m",
    limit_total: int = 10_000,
    drop_timezone: bool = True,
) -> pd.DataFrame:
    """
    Загружает историю свечей Binance пачками по 1000, двигаясь назад во времени.

    Возвращает DataFrame:
    - index: datetime
    - columns: open, high, low, close, volume

    Parameters
    ----------
    symbol : str
        Торговый символ Binance, например BTCUSDT.
    interval : str
        Интервал свечей, например 5m, 15m, 1h.
    limit_total : int
        Сколько свечей максимум загрузить.
    drop_timezone : bool
        Если True, убирает timezone из индекса.
        Для Backtrader обычно так удобнее.
    """
    url = "https://api.binance.com/api/v3/klines"
    per_request = 1000
    all_klines = []
    end_time = None

    with requests.Session() as session:
        session.trust_env = False

        while len(all_klines) < limit_total:
            params = {
                "symbol": symbol,
                "interval": interval,
                "limit": per_request,
            }

            if end_time is not None:
                params["endTime"] = end_time - 1

            resp = session.get(url, params=params, timeout=20)
            resp.raise_for_status()
            klines = resp.json()

            if not klines:
                break

            all_klines = klines + all_klines
            end_time = klines[0][0]

            if len(klines) < per_request:
                break

            time.sleep(0.1)

    if not all_klines:
        raise ValueError("Binance returned no klines.")

    all_klines = all_klines[-limit_total:]

    df = pd.DataFrame(
        all_klines,
        columns=[
            "open_time", "open", "high", "low", "close", "volume",
            "close_time", "quote_asset_volume", "number_of_trades",
            "taker_buy_base_asset_volume", "taker_buy_quote_asset_volume", "ignore"
        ]
    )

    # Числовые колонки
    numeric_cols = ["open", "high", "low", "close", "volume"]
    for col in numeric_cols:
        df[col] = pd.to_numeric(df[col], errors="coerce")

    # Дата
    df["datetime"] = pd.to_datetime(df["open_time"], unit="ms", utc=True)

    # Оставляем только то, что нужно стратегии
    df = df[["datetime", "open", "high", "low", "close", "volume"]].copy()

    # Сортировка, удаление дублей, удаление пропусков
    df = df.sort_values("datetime")
    df = df.drop_duplicates(subset=["datetime"])
    df = df.dropna(subset=["open", "high", "low", "close", "volume"])

    # Индекс
    df = df.set_index("datetime")

    # Для Backtrader обычно удобнее naive datetime index
    if drop_timezone:
        df.index = df.index.tz_convert(None)

    # Финальная сортировка на всякий случай
    df = df.sort_index()

    # Базовая проверка
    if df.empty:
        raise ValueError("Prepared DataFrame is empty.")

    expected_cols = ["open", "high", "low", "close", "volume"]
    if list(df.columns) != expected_cols:
        raise ValueError(f"Unexpected columns: {df.columns.tolist()}")

    return df


# ====== Параметры загрузки ======
SYMBOL = "BTCUSDT"
INTERVAL = "5m"
LIMIT_TOTAL = 100_000


# ====== Загрузка ======
df = load_binance_klines(
    symbol=SYMBOL,
    interval=INTERVAL,
    limit_total=LIMIT_TOTAL,
    drop_timezone=True,
)


# ====== Проверка ======
print("Data loaded successfully")
print(f"Symbol: {SYMBOL}")
print(f"Interval: {INTERVAL}")
print(f"Rows: {len(df):,}")
print(f"Columns: {df.columns.tolist()}")
print(f"Index type: {type(df.index)}")
print(f"Timezone: {df.index.tz}")
print(f"Date range: {df.index.min()} -> {df.index.max()}")
print("\nMissing values:")
print(df.isna().sum())
print("\nDuplicated index:", df.index.duplicated().sum())

display(df.head())
display(df.tail())
# Out:
# Data loaded successfully
# Symbol: BTCUSDT
# Interval: 5m
# Rows: 100,000
# Columns: ['open', 'high', 'low', 'close', 'volume']
# Index type: <class 'pandas.DatetimeIndex'>
# Timezone: None
# Date range: 2025-05-02 08:10:00 -> 2026-04-14 13:25:00
#
# Missing values:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
#
# Duplicated index: 0
#                          open      high       low     close    volume
# datetime
# 2025-05-02 08:10:00  96499.37  96579.37  96484.49  96567.54  51.80262
# 2025-05-02 08:15:00  96567.54  96658.00  96540.19  96657.99  64.77434
# 2025-05-02 08:20:00  96658.00  96665.98  96646.35  96650.95  17.13931
# 2025-05-02 08:25:00  96650.95  96651.05  96594.33  96626.05  19.74307
# 2025-05-02 08:30:00  96626.05  96626.05  96477.51  96481.42  78.81045
#                          open      high       low     close    volume
# datetime
# 2026-04-14 13:05:00  74597.78  74613.13  74537.50  74583.65  54.92491
# 2026-04-14 13:10:00  74583.65  74583.65  74528.38  74576.51  31.12883
# 2026-04-14 13:15:00  74576.52  74681.13  74555.00  74621.91  56.13021
# 2026-04-14 13:20:00  74621.91  74732.94  74621.90  74712.88  58.10288
# 2026-04-14 13:25:00  74712.89  74712.89  74703.26  74703.26   1.17239

# %% [markdown]
# # Быстрый одиночный прогон

# %%
result = run_backtest_bt(
    df=df,
    strategy_params=DEFAULT_PARAMS,
    initial_cash=10_000,
    commission=0.0004,
    slippage_perc=0.0002,
    plot=False,
)

print(result["metrics"])
result["trades_df"].tail()
# Out:
# {'initial_cash': 10000.0, 'final_value': 10116.283718469509, 'net_profit': 116.28371846950904, 'total_return_pct': 1.162837184695098, 'max_drawdown_pct': 1.122741001733133, 'n_trades': 1, 'win_rate_pct': 100.0, 'profit_factor': inf, 'sharpe': 2.3552652976419486}
#            entry_time           exit_time  size      price_in     price_out  \
# 0 2026-03-31 15:15:00 2026-03-31 23:35:00   0.0  67255.158342  67255.158342
#
#     pnl_gross     pnl_net  barlen
# 0  122.941358  116.283718     100

# %% [markdown]
# # График equity curve

# %%
eq = result["equity_df"]

if not eq.empty:
    plt.figure(figsize=(12, 5))
    plt.plot(eq.index, eq["equity"])
    plt.title("Equity Curve")
    plt.xlabel("Date")
    plt.ylabel("Equity")
    plt.grid(True)
    plt.show()

# %% [markdown]
# # Optuna objective

# %%
def make_optuna_objective_bt(
    df: pd.DataFrame,
    initial_cash=10_000.0,
    commission=0.0004,
    slippage_perc=0.0002,
    min_trades=20,
):
    def objective(trial):
        params = dict(
            ema_fast=trial.suggest_int("ema_fast", 10, 50),
            ema_slow=trial.suggest_int("ema_slow", 100, 300),
            atr_period=trial.suggest_int("atr_period", 7, 30),
            volume_window=trial.suggest_int("volume_window", 10, 50),
            swing_window=trial.suggest_int("swing_window", 5, 30),
            slope_lookback=trial.suggest_int("slope_lookback", 5, 30),

            pullback_min_pct=trial.suggest_float("pullback_min_pct", 0.001, 0.01),
            pullback_max_pct=trial.suggest_float("pullback_max_pct", 0.01, 0.06),
            max_close_above_fast_ema_pct=trial.suggest_float("max_close_above_fast_ema_pct", 0.002, 0.03),
            min_volume_ratio=trial.suggest_float("min_volume_ratio", 0.8, 2.0),
            min_atr_pct=trial.suggest_float("min_atr_pct", 0.001, 0.02),
            max_atr_pct=trial.suggest_float("max_atr_pct", 0.02, 0.15),
            use_breakout_trigger=trial.suggest_categorical("use_breakout_trigger", [True, False]),

            risk_per_trade=trial.suggest_float("risk_per_trade", 0.002, 0.02),
            rr_target=trial.suggest_float("rr_target", 1.0, 4.0),
            atr_stop_mult=trial.suggest_float("atr_stop_mult", 0.8, 3.0),
            max_bars_in_trade=trial.suggest_int("max_bars_in_trade", 10, 300),
            debug=False,
        )

        if params["ema_fast"] >= params["ema_slow"]:
            return -1e9
        if params["pullback_min_pct"] >= params["pullback_max_pct"]:
            return -1e9

        try:
            result = run_backtest_bt(
                df=df,
                strategy_params=params,
                initial_cash=initial_cash,
                commission=commission,
                slippage_perc=slippage_perc,
                plot=False,
            )
            metrics = result["metrics"]
        except Exception:
            return -1e9

        n_trades = metrics["n_trades"]
        total_return = metrics["total_return_pct"]
        max_dd = abs(metrics["max_drawdown_pct"])
        pf = metrics["profit_factor"]
        sharpe = metrics["sharpe"]

        if n_trades < min_trades:
            return -1e6 + n_trades

        score = (
            total_return * 1.0
            + min(pf, 5.0) * 10.0
            + (0.0 if not np.isfinite(sharpe) else sharpe) * 10.0
            - max_dd * 1.2
        )

        return score

    return objective

# %% [markdown]
# # запуск Optuna

# %%
import optuna

objective = make_optuna_objective_bt(
    df=df,
    initial_cash=10_000,
    commission=0.0004,
    slippage_perc=0.0002,
    min_trades=1,
)

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=10)

print("Best value:", study.best_value)
print("Best params:", study.best_params)
# Out:
# [I 2026-04-14 16:26:05,741] A new study created in memory with name: no-name-3f83fdee-d2a4-4042-b981-a9d2d55745e1
# [I 2026-04-14 16:26:15,983] Trial 0 finished with value: -1000000.0 and parameters: {'ema_fast': 47, 'ema_slow': 272, 'atr_period': 25, 'volume_window': 18, 'swing_window': 10, 'slope_lookback': 12, 'pullback_min_pct': 0.007402802692790302, 'pullback_max_pct': 0.05877840468053184, 'max_close_above_fast_ema_pct': 0.016251536485695113, 'min_volume_ratio': 1.8711970084934297, 'min_atr_pct': 0.013624334778722453, 'max_atr_pct': 0.14255548279844465, 'use_breakout_trigger': True, 'risk_per_trade': 0.012505860452280634, 'rr_target': 3.8737436902458953, 'atr_stop_mult': 0.9823098417929205, 'max_bars_in_trade': 161}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:26:26,145] Trial 1 finished with value: -1000000.0 and parameters: {'ema_fast': 31, 'ema_slow': 267, 'atr_period': 24, 'volume_window': 15, 'swing_window': 19, 'slope_lookback': 5, 'pullback_min_pct': 0.008243672172301066, 'pullback_max_pct': 0.034459076136028624, 'max_close_above_fast_ema_pct': 0.026464288178192096, 'min_volume_ratio': 1.513939546461916, 'min_atr_pct': 0.012060302030156483, 'max_atr_pct': 0.10977057412549188, 'use_breakout_trigger': False, 'risk_per_trade': 0.007337138370885844, 'rr_target': 2.9127184001804016, 'atr_stop_mult': 1.6606686294588835, 'max_bars_in_trade': 153}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:26:36,253] Trial 2 finished with value: 3.5290361982368204 and parameters: {'ema_fast': 23, 'ema_slow': 143, 'atr_period': 21, 'volume_window': 47, 'swing_window': 27, 'slope_lookback': 5, 'pullback_min_pct': 0.004341664127146422, 'pullback_max_pct': 0.017173185340446057, 'max_close_above_fast_ema_pct': 0.004774307001176545, 'min_volume_ratio': 1.3935409131628362, 'min_atr_pct': 0.0010823616346346166, 'max_atr_pct': 0.06785393241164726, 'use_breakout_trigger': True, 'risk_per_trade': 0.007488756814073115, 'rr_target': 2.689765711039281, 'atr_stop_mult': 2.0009129688758502, 'max_bars_in_trade': 169}. Best is trial 2 with value: 3.5290361982368204.
# [I 2026-04-14 16:26:46,468] Trial 3 finished with value: -1000000.0 and parameters: {'ema_fast': 38, 'ema_slow': 278, 'atr_period': 24, 'volume_window': 33, 'swing_window': 9, 'slope_lookback': 10, 'pullback_min_pct': 0.003314074592864591, 'pullback_max_pct': 0.030390604205912726, 'max_close_above_fast_ema_pct': 0.02656769086140076, 'min_volume_ratio': 1.66071469355566, 'min_atr_pct': 0.012018399259028853, 'max_atr_pct': 0.061083786626853265, 'use_breakout_trigger': True, 'risk_per_trade': 0.019950616324072114, 'rr_target': 1.6595775503693628, 'atr_stop_mult': 2.493156948595673, 'max_bars_in_trade': 122}. Best is trial 2 with value: 3.5290361982368204.
# [I 2026-04-14 16:26:56,765] Trial 4 finished with value: -1000000.0 and parameters: {'ema_fast': 15, 'ema_slow': 231, 'atr_period': 8, 'volume_window': 43, 'swing_window': 19, 'slope_lookback': 26, 'pullback_min_pct': 0.0076931284016408955, 'pullback_max_pct': 0.013721575388658255, 'max_close_above_fast_ema_pct': 0.0288262030235878, 'min_volume_ratio': 0.8985123061782245, 'min_atr_pct': 0.006612418050794675, 'max_atr_pct': 0.1437350055283435, 'use_breakout_trigger': True, 'risk_per_trade': 0.007222215679060666, 'rr_target': 2.3081875853780818, 'atr_stop_mult': 1.5015109724032911, 'max_bars_in_trade': 44}. Best is trial 2 with value: 3.5290361982368204.
# [I 2026-04-14 16:27:06,610] Trial 5 finished with value: -1000000.0 and parameters: {'ema_fast': 28, 'ema_slow': 152, 'atr_period': 24, 'volume_window': 44, 'swing_window': 13, 'slope_lookback': 27, 'pullback_min_pct': 0.009125146018341763, 'pullback_max_pct': 0.05866765092764073, 'max_close_above_fast_ema_pct': 0.026766512927845237, 'min_volume_ratio': 1.399109586757128, 'min_atr_pct': 0.006241013734735502, 'max_atr_pct': 0.06134863286512335, 'use_breakout_trigger': True, 'risk_per_trade': 0.015315240472987232, 'rr_target': 3.2444873742528086, 'atr_stop_mult': 1.798987629984779, 'max_bars_in_trade': 244}. Best is trial 2 with value: 3.5290361982368204.
# [I 2026-04-14 16:27:16,737] Trial 6 finished with value: -1000000.0 and parameters: {'ema_fast': 27, 'ema_slow': 260, 'atr_period': 7, 'volume_window': 28, 'swing_window': 11, 'slope_lookback': 6, 'pullback_min_pct': 0.006718166673097849, 'pullback_max_pct': 0.05048242605152062, 'max_close_above_fast_ema_pct': 0.029691941249958664, 'min_volume_ratio': 1.698049774954603, 'min_atr_pct': 0.003906232829016563, 'max_atr_pct': 0.11038452113249059, 'use_breakout_trigger': True, 'risk_per_trade': 0.008203597754370105, 'rr_target': 3.240460392630337, 'atr_stop_mult': 2.4811239676594328, 'max_bars_in_trade': 53}. Best is trial 2 with value: 3.5290361982368204.
# [I 2026-04-14 16:27:26,565] Trial 7 finished with value: -1000000.0 and parameters: {'ema_fast': 39, 'ema_slow': 183, 'atr_period': 22, 'volume_window': 36, 'swing_window': 25, 'slope_lookback': 25, 'pullback_min_pct': 0.005605270088360122, 'pullback_max_pct': 0.04690572454903096, 'max_close_above_fast_ema_pct': 0.021846874105010412, 'min_volume_ratio': 1.4125800865748683, 'min_atr_pct': 0.019149410557834513, 'max_atr_pct': 0.07886228156613458, 'use_breakout_trigger': True, 'risk_per_trade': 0.006637626998461235, 'rr_target': 1.5966157817985236, 'atr_stop_mult': 2.9860646636791497, 'max_bars_in_trade': 155}. Best is trial 2 with value: 3.5290361982368204.
# [I 2026-04-14 16:27:36,415] Trial 8 finished with value: -1000000.0 and parameters: {'ema_fast': 30, 'ema_slow': 191, 'atr_period': 11, 'volume_window': 43, 'swing_window': 15, 'slope_lookback': 9, 'pullback_min_pct': 0.004475903514101511, 'pullback_max_pct': 0.020910760973992366, 'max_close_above_fast_ema_pct': 0.017024602427457396, 'min_volume_ratio': 1.60858112701268, 'min_atr_pct': 0.00435258463120159, 'max_atr_pct': 0.13824384747684884, 'use_breakout_trigger': True, 'risk_per_trade': 0.011744965838065861, 'rr_target': 1.483566403885069, 'atr_stop_mult': 2.3042416504329237, 'max_bars_in_trade': 90}. Best is trial 2 with value: 3.5290361982368204.
# [I 2026-04-14 16:27:46,194] Trial 9 finished with value: -1000000.0 and parameters: {'ema_fast': 16, 'ema_slow': 217, 'atr_period': 10, 'volume_window': 49, 'swing_window': 15, 'slope_lookback': 17, 'pullback_min_pct': 0.007005636793116694, 'pullback_max_pct': 0.030834641066609582, 'max_close_above_fast_ema_pct': 0.023113677391284962, 'min_volume_ratio': 1.461604932642362, 'min_atr_pct': 0.01755942520674804, 'max_atr_pct': 0.12948751548434506, 'use_breakout_trigger': True, 'risk_per_trade': 0.00961987108724157, 'rr_target': 1.4460946149771805, 'atr_stop_mult': 2.037336489135756, 'max_bars_in_trade': 33}. Best is trial 2 with value: 3.5290361982368204.
# Best value: 3.5290361982368204
# Best params: {'ema_fast': 23, 'ema_slow': 143, 'atr_period': 21, 'volume_window': 47, 'swing_window': 27, 'slope_lookback': 5, 'pullback_min_pct': 0.004341664127146422, 'pullback_max_pct': 0.017173185340446057, 'max_close_above_fast_ema_pct': 0.004774307001176545, 'min_volume_ratio': 1.3935409131628362, 'min_atr_pct': 0.0010823616346346166, 'max_atr_pct': 0.06785393241164726, 'use_breakout_trigger': True, 'risk_per_trade': 0.007488756814073115, 'rr_target': 2.689765711039281, 'atr_stop_mult': 2.0009129688758502, 'max_bars_in_trade': 169}

# %% [markdown]
# # Прогон лучших параметров после Optuna

# %%
best_params = study.best_params.copy()
best_params["debug"] = False

best_result = run_backtest_bt(
    df=df,
    strategy_params=best_params,
    initial_cash=10_000,
    commission=0.0004,
    slippage_perc=0.0002,
    plot=False,
)

print(best_result["metrics"])
best_result["trades_df"].tail()
# Out:
# {'initial_cash': 10000.0, 'final_value': 10006.567075843066, 'net_profit': 6.56707584306605, 'total_return_pct': 0.06567075843066927, 'max_drawdown_pct': 2.1422616106485624, 'n_trades': 5, 'win_rate_pct': 40.0, 'profit_factor': 1.0265452130516735, 'sharpe': -0.423137275793231}
#            entry_time           exit_time  size       price_in      price_out  \
# 0 2025-10-27 00:15:00 2025-10-27 14:20:00   0.0  114895.104426  114895.104426
# 1 2026-02-07 01:50:00 2026-02-07 06:55:00   0.0   70548.096798   70548.096798
# 2 2026-03-09 07:55:00 2026-03-09 14:35:00   0.0   67531.043508   67531.043508
# 3 2026-03-20 11:15:00 2026-03-20 13:35:00   0.0   70779.350000   70779.350000
# 4 2026-03-30 01:50:00 2026-03-30 15:55:00   0.0   66764.690000   66764.690000
#
#     pnl_gross     pnl_net  barlen
# 0  -16.658707  -21.340031     169
# 1 -109.668879 -114.793605      61
# 2  190.576825  184.491120      80
# 3 -103.700415 -111.258458      28
# 4   73.620220   69.468050     169

# %% [markdown]
# # Вспомогательные функции для WFA

# %%
def slice_df_by_date(df: pd.DataFrame, start, end):
    return df.loc[(df.index >= pd.Timestamp(start)) & (df.index < pd.Timestamp(end))].copy()


def generate_wfa_windows(
    df: pd.DataFrame,
    train_months=12,
    test_months=3,
    step_months=3,
    anchored=False,
):
    if not isinstance(df.index, pd.DatetimeIndex):
        raise ValueError("DataFrame index must be DatetimeIndex")

    start_date = df.index.min().normalize()
    end_date = df.index.max().normalize()

    windows = []
    cursor = start_date + relativedelta(months=train_months)

    while True:
        test_start = cursor
        test_end = test_start + relativedelta(months=test_months)

        if test_end > end_date:
            break

        if anchored:
            train_start = start_date
        else:
            train_start = test_start - relativedelta(months=train_months)

        train_end = test_start

        train_df = slice_df_by_date(df, train_start, train_end)
        test_df = slice_df_by_date(df, test_start, test_end)

        if len(train_df) > 0 and len(test_df) > 0:
            windows.append({
                "train_start": train_start,
                "train_end": train_end,
                "test_start": test_start,
                "test_end": test_end,
                "n_train": len(train_df),
                "n_test": len(test_df),
            })

        cursor = cursor + relativedelta(months=step_months)

    return windows

# %% [markdown]
# # Основной WFA runner

# %%
def run_walk_forward_analysis(
    df: pd.DataFrame,
    train_months=12,
    test_months=3,
    step_months=3,
    anchored=False,
    n_trials=50,
    initial_cash=10_000.0,
    commission=0.0004,
    slippage_perc=0.0002,
    min_trades_train=20,
    study_factory=None,
    verbose=True,
):
    import optuna

    windows = generate_wfa_windows(
        df=df,
        train_months=train_months,
        test_months=test_months,
        step_months=step_months,
        anchored=anchored,
    )

    all_results = []
    oos_equity_parts = []
    all_oos_trades = []

    for i, w in enumerate(windows, start=1):
        train_df = slice_df_by_date(df, w["train_start"], w["train_end"])
        test_df = slice_df_by_date(df, w["test_start"], w["test_end"])

        if verbose:
            print(
                f"\nWFA window {i}/{len(windows)} | "
                f"TRAIN: {w['train_start'].date()} -> {w['train_end'].date()} | "
                f"TEST: {w['test_start'].date()} -> {w['test_end'].date()}"
            )

        objective = make_optuna_objective_bt(
            df=train_df,
            initial_cash=initial_cash,
            commission=commission,
            slippage_perc=slippage_perc,
            min_trades=min_trades_train,
        )

        study = study_factory() if study_factory is not None else optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=n_trials, show_progress_bar=False)

        best_params = study.best_params.copy()
        best_params["debug"] = False

        is_result = run_backtest_bt(
            df=train_df,
            strategy_params=best_params,
            initial_cash=initial_cash,
            commission=commission,
            slippage_perc=slippage_perc,
            plot=False,
        )

        oos_result = run_backtest_bt(
            df=test_df,
            strategy_params=best_params,
            initial_cash=initial_cash,
            commission=commission,
            slippage_perc=slippage_perc,
            plot=False,
        )

        is_metrics = is_result["metrics"]
        oos_metrics = oos_result["metrics"]

        row = {
            "window_id": i,
            "train_start": w["train_start"],
            "train_end": w["train_end"],
            "test_start": w["test_start"],
            "test_end": w["test_end"],

            "is_return_pct": is_metrics["total_return_pct"],
            "is_max_dd_pct": is_metrics["max_drawdown_pct"],
            "is_n_trades": is_metrics["n_trades"],
            "is_pf": is_metrics["profit_factor"],
            "is_sharpe": is_metrics["sharpe"],

            "oos_return_pct": oos_metrics["total_return_pct"],
            "oos_max_dd_pct": oos_metrics["max_drawdown_pct"],
            "oos_n_trades": oos_metrics["n_trades"],
            "oos_pf": oos_metrics["profit_factor"],
            "oos_sharpe": oos_metrics["sharpe"],

            "best_value": study.best_value,
            "best_params": best_params,
        }
        all_results.append(row)

        oos_trades = oos_result["trades_df"].copy()
        if not oos_trades.empty:
            oos_trades["window_id"] = i
            all_oos_trades.append(oos_trades)

        oos_eq = oos_result["equity_df"].copy()
        if not oos_eq.empty:
            oos_eq = oos_eq.rename(columns={"equity": f"equity_window_{i}"})
            oos_equity_parts.append((i, oos_eq))

        if verbose:
            print(
                f"  IS  | return={is_metrics['total_return_pct']:.2f}% | dd={is_metrics['max_drawdown_pct']:.2f}% | "
                f"trades={is_metrics['n_trades']} | pf={is_metrics['profit_factor']:.2f}"
            )
            print(
                f"  OOS | return={oos_metrics['total_return_pct']:.2f}% | dd={oos_metrics['max_drawdown_pct']:.2f}% | "
                f"trades={oos_metrics['n_trades']} | pf={oos_metrics['profit_factor']:.2f}"
            )

    results_df = pd.DataFrame(all_results)

    stitched_oos = []
    current_capital = initial_cash

    for i, eq_df in oos_equity_parts:
        col = f"equity_window_{i}"
        temp = eq_df.copy().sort_index()

        base = temp[col].iloc[0]
        if base <= 0:
            continue

        scaled = temp[col] / base * current_capital
        current_capital = float(scaled.iloc[-1])

        stitched_oos.append(pd.DataFrame({"equity": scaled}))

    if stitched_oos:
        stitched_oos_equity = pd.concat(stitched_oos).sort_index()
        stitched_oos_equity = stitched_oos_equity[~stitched_oos_equity.index.duplicated(keep="last")]
    else:
        stitched_oos_equity = pd.DataFrame(columns=["equity"])

    if all_oos_trades:
        all_oos_trades_df = pd.concat(all_oos_trades, ignore_index=True)
    else:
        all_oos_trades_df = pd.DataFrame()

    if not stitched_oos_equity.empty:
        peak = stitched_oos_equity["equity"].cummax()
        dd = stitched_oos_equity["equity"] / peak - 1
        stitched_return_pct = (stitched_oos_equity["equity"].iloc[-1] / initial_cash - 1) * 100
        stitched_max_dd_pct = dd.min() * 100
    else:
        stitched_return_pct = 0.0
        stitched_max_dd_pct = 0.0

    summary = {
        "n_windows": len(results_df),
        "avg_is_return_pct": float(results_df["is_return_pct"].mean()) if not results_df.empty else 0.0,
        "avg_oos_return_pct": float(results_df["oos_return_pct"].mean()) if not results_df.empty else 0.0,
        "median_oos_return_pct": float(results_df["oos_return_pct"].median()) if not results_df.empty else 0.0,
        "avg_oos_pf": float(results_df["oos_pf"].replace([np.inf, -np.inf], np.nan).mean()) if not results_df.empty else 0.0,
        "stitched_oos_return_pct": float(stitched_return_pct),
        "stitched_oos_max_dd_pct": float(stitched_max_dd_pct),
    }

    return {
        "windows_df": results_df,
        "stitched_oos_equity": stitched_oos_equity,
        "all_oos_trades_df": all_oos_trades_df,
        "summary": summary,
    }

# %% [markdown]
# # запуск WFA

# %%
wfa_result = run_walk_forward_analysis(
    df=df,
    train_months=4,
    test_months=1,
    step_months=1,
    anchored=False,
    n_trials=60,
    initial_cash=10_000,
    commission=0.0004,
    slippage_perc=0.0002,
    min_trades_train=8,
    verbose=True,
)

print(wfa_result["summary"])
wfa_result["windows_df"].head()
# Out:
# [I 2026-04-14 16:28:41,334] A new study created in memory with name: no-name-db82e73d-d09c-4ff4-8bc8-b38fb01de93c
# WFA window 1/7 | TRAIN: 2025-05-02 -> 2025-09-02 | TEST: 2025-09-02 -> 2025-10-02
# [I 2026-04-14 16:28:44,870] Trial 0 finished with value: -1000000.0 and parameters: {'ema_fast': 44, 'ema_slow': 222, 'atr_period': 25, 'volume_window': 18, 'swing_window': 27, 'slope_lookback': 8, 'pullback_min_pct': 0.009095194136540054, 'pullback_max_pct': 0.010148633996499554, 'max_close_above_fast_ema_pct': 0.02748821670094187, 'min_volume_ratio': 1.3843695895619266, 'min_atr_pct': 0.013529133284713023, 'max_atr_pct': 0.09962364496389706, 'use_breakout_trigger': True, 'risk_per_trade': 0.0071539202179907516, 'rr_target': 3.1838935397125736, 'atr_stop_mult': 1.3177241667250796, 'max_bars_in_trade': 170}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:28:48,385] Trial 1 finished with value: -1000000.0 and parameters: {'ema_fast': 36, 'ema_slow': 168, 'atr_period': 18, 'volume_window': 43, 'swing_window': 29, 'slope_lookback': 24, 'pullback_min_pct': 0.009086570773878033, 'pullback_max_pct': 0.019044586702798752, 'max_close_above_fast_ema_pct': 0.02414609582635433, 'min_volume_ratio': 1.2070345363330484, 'min_atr_pct': 0.002190596307435614, 'max_atr_pct': 0.11827767987422139, 'use_breakout_trigger': False, 'risk_per_trade': 0.012112537700771921, 'rr_target': 2.901018339834528, 'atr_stop_mult': 2.3731028325355603, 'max_bars_in_trade': 13}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:28:51,976] Trial 2 finished with value: -1000000.0 and parameters: {'ema_fast': 22, 'ema_slow': 150, 'atr_period': 16, 'volume_window': 48, 'swing_window': 19, 'slope_lookback': 15, 'pullback_min_pct': 0.009813683664978774, 'pullback_max_pct': 0.03764817187937645, 'max_close_above_fast_ema_pct': 0.021813826642305065, 'min_volume_ratio': 1.4664883442314594, 'min_atr_pct': 0.013968800793933263, 'max_atr_pct': 0.04900790755264988, 'use_breakout_trigger': False, 'risk_per_trade': 0.014389893773019113, 'rr_target': 1.0699708375495467, 'atr_stop_mult': 2.2279770436439303, 'max_bars_in_trade': 120}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:28:55,694] Trial 3 finished with value: -1000000.0 and parameters: {'ema_fast': 22, 'ema_slow': 293, 'atr_period': 18, 'volume_window': 12, 'swing_window': 10, 'slope_lookback': 22, 'pullback_min_pct': 0.0036254663244014943, 'pullback_max_pct': 0.02334828944549504, 'max_close_above_fast_ema_pct': 0.00804354813286218, 'min_volume_ratio': 0.9103617994331014, 'min_atr_pct': 0.014652592218011573, 'max_atr_pct': 0.06931448306480492, 'use_breakout_trigger': False, 'risk_per_trade': 0.006155750668885605, 'rr_target': 3.7249992318715712, 'atr_stop_mult': 0.9181438718513506, 'max_bars_in_trade': 52}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:28:59,308] Trial 4 finished with value: -1000000.0 and parameters: {'ema_fast': 15, 'ema_slow': 145, 'atr_period': 9, 'volume_window': 41, 'swing_window': 23, 'slope_lookback': 18, 'pullback_min_pct': 0.007559248454525199, 'pullback_max_pct': 0.053391316647543055, 'max_close_above_fast_ema_pct': 0.024425931999984087, 'min_volume_ratio': 1.964682243903917, 'min_atr_pct': 0.005699277900233891, 'max_atr_pct': 0.1478235602726808, 'use_breakout_trigger': False, 'risk_per_trade': 0.019892381258598088, 'rr_target': 1.5645867053958806, 'atr_stop_mult': 2.9464230663881574, 'max_bars_in_trade': 218}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:03,005] Trial 5 finished with value: -1000000.0 and parameters: {'ema_fast': 44, 'ema_slow': 258, 'atr_period': 26, 'volume_window': 39, 'swing_window': 19, 'slope_lookback': 17, 'pullback_min_pct': 0.0045990236779536835, 'pullback_max_pct': 0.03372239234468244, 'max_close_above_fast_ema_pct': 0.013852169439334153, 'min_volume_ratio': 1.324012213202114, 'min_atr_pct': 0.003175820828728324, 'max_atr_pct': 0.03399928810663229, 'use_breakout_trigger': True, 'risk_per_trade': 0.008945962145314634, 'rr_target': 3.0524877771329155, 'atr_stop_mult': 1.6301183845924863, 'max_bars_in_trade': 107}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:06,654] Trial 6 finished with value: -1000000.0 and parameters: {'ema_fast': 37, 'ema_slow': 298, 'atr_period': 26, 'volume_window': 33, 'swing_window': 15, 'slope_lookback': 14, 'pullback_min_pct': 0.005298413998388188, 'pullback_max_pct': 0.015732194150758712, 'max_close_above_fast_ema_pct': 0.017679882588519727, 'min_volume_ratio': 1.1506143056680942, 'min_atr_pct': 0.01009705114994957, 'max_atr_pct': 0.12069375930775875, 'use_breakout_trigger': False, 'risk_per_trade': 0.01167046101668105, 'rr_target': 3.4606731772913046, 'atr_stop_mult': 1.3795384323158317, 'max_bars_in_trade': 44}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:10,404] Trial 7 finished with value: -1000000.0 and parameters: {'ema_fast': 22, 'ema_slow': 223, 'atr_period': 8, 'volume_window': 18, 'swing_window': 6, 'slope_lookback': 16, 'pullback_min_pct': 0.006609483551864049, 'pullback_max_pct': 0.04478454104752355, 'max_close_above_fast_ema_pct': 0.022120981672077135, 'min_volume_ratio': 1.9474152310375978, 'min_atr_pct': 0.012478662414407656, 'max_atr_pct': 0.10947317367114712, 'use_breakout_trigger': False, 'risk_per_trade': 0.005930282316573062, 'rr_target': 1.623778546760176, 'atr_stop_mult': 2.0857335764955787, 'max_bars_in_trade': 279}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:14,068] Trial 8 finished with value: -1000000.0 and parameters: {'ema_fast': 21, 'ema_slow': 296, 'atr_period': 25, 'volume_window': 40, 'swing_window': 30, 'slope_lookback': 5, 'pullback_min_pct': 0.0015757784901510802, 'pullback_max_pct': 0.04636887313541676, 'max_close_above_fast_ema_pct': 0.003533385239125258, 'min_volume_ratio': 1.1918009302489705, 'min_atr_pct': 0.016730934184194315, 'max_atr_pct': 0.08946342695452388, 'use_breakout_trigger': True, 'risk_per_trade': 0.012825230365324956, 'rr_target': 3.715068816023053, 'atr_stop_mult': 1.7938227850674997, 'max_bars_in_trade': 203}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:17,781] Trial 9 finished with value: -1000000.0 and parameters: {'ema_fast': 13, 'ema_slow': 103, 'atr_period': 9, 'volume_window': 10, 'swing_window': 17, 'slope_lookback': 14, 'pullback_min_pct': 0.001642574327149353, 'pullback_max_pct': 0.0367848409539671, 'max_close_above_fast_ema_pct': 0.02793656759696752, 'min_volume_ratio': 1.9228636945008308, 'min_atr_pct': 0.010621594617847323, 'max_atr_pct': 0.040120218799130275, 'use_breakout_trigger': True, 'risk_per_trade': 0.0027119120637163095, 'rr_target': 3.6728508612055353, 'atr_stop_mult': 1.8632784915704996, 'max_bars_in_trade': 239}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:21,439] Trial 10 finished with value: -1000000.0 and parameters: {'ema_fast': 49, 'ema_slow': 214, 'atr_period': 30, 'volume_window': 24, 'swing_window': 24, 'slope_lookback': 5, 'pullback_min_pct': 0.008314521765982711, 'pullback_max_pct': 0.010609977506361985, 'max_close_above_fast_ema_pct': 0.028574597941206783, 'min_volume_ratio': 1.6495559123131027, 'min_atr_pct': 0.019140073168407122, 'max_atr_pct': 0.07874061741871391, 'use_breakout_trigger': True, 'risk_per_trade': 0.0020460396844190053, 'rr_target': 2.2835171799143574, 'atr_stop_mult': 0.8125376725321652, 'max_bars_in_trade': 161}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:25,135] Trial 11 finished with value: -1000000.0 and parameters: {'ema_fast': 35, 'ema_slow': 173, 'atr_period': 21, 'volume_window': 28, 'swing_window': 30, 'slope_lookback': 30, 'pullback_min_pct': 0.00970905695870802, 'pullback_max_pct': 0.021475650333447744, 'max_close_above_fast_ema_pct': 0.0295238501778537, 'min_volume_ratio': 1.5397394679641436, 'min_atr_pct': 0.0070101149141780835, 'max_atr_pct': 0.11903894278360208, 'use_breakout_trigger': True, 'risk_per_trade': 0.016166786911365492, 'rr_target': 2.746741072121771, 'atr_stop_mult': 2.6286734713551545, 'max_bars_in_trade': 14}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:28,970] Trial 12 finished with value: -1000000.0 and parameters: {'ema_fast': 40, 'ema_slow': 190, 'atr_period': 14, 'volume_window': 20, 'swing_window': 26, 'slope_lookback': 26, 'pullback_min_pct': 0.008327973629176769, 'pullback_max_pct': 0.023003438734783027, 'max_close_above_fast_ema_pct': 0.01655511300569651, 'min_volume_ratio': 0.9323807190837289, 'min_atr_pct': 0.0017174305582299827, 'max_atr_pct': 0.09994675214314772, 'use_breakout_trigger': False, 'risk_per_trade': 0.009404601041570853, 'rr_target': 2.4405620370151104, 'atr_stop_mult': 1.2245074877067026, 'max_bars_in_trade': 129}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:32,649] Trial 13 finished with value: -1000000.0 and parameters: {'ema_fast': 31, 'ema_slow': 240, 'atr_period': 21, 'volume_window': 48, 'swing_window': 27, 'slope_lookback': 10, 'pullback_min_pct': 0.006737666594500381, 'pullback_max_pct': 0.012025402268603026, 'max_close_above_fast_ema_pct': 0.024149129092564624, 'min_volume_ratio': 1.1624615001564622, 'min_atr_pct': 0.007560097749910116, 'max_atr_pct': 0.14320686152235065, 'use_breakout_trigger': True, 'risk_per_trade': 0.00688977191654085, 'rr_target': 3.0600672040274453, 'atr_stop_mult': 2.418166388343542, 'max_bars_in_trade': 159}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:36,287] Trial 14 finished with value: -1000000.0 and parameters: {'ema_fast': 50, 'ema_slow': 173, 'atr_period': 13, 'volume_window': 32, 'swing_window': 22, 'slope_lookback': 22, 'pullback_min_pct': 0.00891643940259947, 'pullback_max_pct': 0.028127045078952882, 'max_close_above_fast_ema_pct': 0.019380552432107852, 'min_volume_ratio': 1.6815628527135669, 'min_atr_pct': 0.009644496650570312, 'max_atr_pct': 0.12959115384747527, 'use_breakout_trigger': False, 'risk_per_trade': 0.016287146344795993, 'rr_target': 3.1156935409969435, 'atr_stop_mult': 1.4447962208662217, 'max_bars_in_trade': 84}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:39,888] Trial 15 finished with value: -1000000.0 and parameters: {'ema_fast': 42, 'ema_slow': 118, 'atr_period': 22, 'volume_window': 17, 'swing_window': 27, 'slope_lookback': 10, 'pullback_min_pct': 0.00687689883058948, 'pullback_max_pct': 0.01758954614740088, 'max_close_above_fast_ema_pct': 0.01237467680790522, 'min_volume_ratio': 1.2807582538100968, 'min_atr_pct': 0.004375095848541375, 'max_atr_pct': 0.0971104819764184, 'use_breakout_trigger': True, 'risk_per_trade': 0.009372174453006482, 'rr_target': 2.15436168820829, 'atr_stop_mult': 2.6523549789040004, 'max_bars_in_trade': 202}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:43,438] Trial 16 finished with value: -1000000.0 and parameters: {'ema_fast': 31, 'ema_slow': 195, 'atr_period': 30, 'volume_window': 27, 'swing_window': 30, 'slope_lookback': 22, 'pullback_min_pct': 0.008687524656612707, 'pullback_max_pct': 0.028758260706111777, 'max_close_above_fast_ema_pct': 0.026041809621797536, 'min_volume_ratio': 1.0281183680165447, 'min_atr_pct': 0.016881854434421306, 'max_atr_pct': 0.06676241351009984, 'use_breakout_trigger': True, 'risk_per_trade': 0.00452271158565391, 'rr_target': 2.8087524430517115, 'atr_stop_mult': 1.2029721495615147, 'max_bars_in_trade': 173}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:47,184] Trial 17 finished with value: -1000000.0 and parameters: {'ema_fast': 47, 'ema_slow': 258, 'atr_period': 23, 'volume_window': 36, 'swing_window': 13, 'slope_lookback': 29, 'pullback_min_pct': 0.009896426942345634, 'pullback_max_pct': 0.01702839920650054, 'max_close_above_fast_ema_pct': 0.02034735327400821, 'min_volume_ratio': 1.4082087119208222, 'min_atr_pct': 0.012499425061775465, 'max_atr_pct': 0.13376221052390916, 'use_breakout_trigger': False, 'risk_per_trade': 0.008227989772141684, 'rr_target': 3.32421262150503, 'atr_stop_mult': 2.1230582234471056, 'max_bars_in_trade': 273}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:50,963] Trial 18 finished with value: -1000000.0 and parameters: {'ema_fast': 36, 'ema_slow': 136, 'atr_period': 17, 'volume_window': 43, 'swing_window': 21, 'slope_lookback': 25, 'pullback_min_pct': 0.002917474130664943, 'pullback_max_pct': 0.01064953231541147, 'max_close_above_fast_ema_pct': 0.025793199731664232, 'min_volume_ratio': 0.8020698418950345, 'min_atr_pct': 0.0012900403124087706, 'max_atr_pct': 0.11073102960245204, 'use_breakout_trigger': False, 'risk_per_trade': 0.013009208646270707, 'rr_target': 2.691845044482554, 'atr_stop_mult': 2.4227538435998555, 'max_bars_in_trade': 83}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:55,277] Trial 19 finished with value: -1000000.0 and parameters: {'ema_fast': 45, 'ema_slow': 180, 'atr_period': 14, 'volume_window': 24, 'swing_window': 25, 'slope_lookback': 19, 'pullback_min_pct': 0.005564673437656454, 'pullback_max_pct': 0.058960469429626364, 'max_close_above_fast_ema_pct': 0.029824119512682493, 'min_volume_ratio': 1.608041091433267, 'min_atr_pct': 0.00844029269000172, 'max_atr_pct': 0.057937748383869, 'use_breakout_trigger': True, 'risk_per_trade': 0.010968832994906762, 'rr_target': 1.854001286884124, 'atr_stop_mult': 1.62380140777434, 'max_bars_in_trade': 245}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:29:59,447] Trial 20 finished with value: -1000000.0 and parameters: {'ema_fast': 26, 'ema_slow': 214, 'atr_period': 19, 'volume_window': 14, 'swing_window': 27, 'slope_lookback': 10, 'pullback_min_pct': 0.0075971279166808505, 'pullback_max_pct': 0.0284310990195175, 'max_close_above_fast_ema_pct': 0.02276415629061108, 'min_volume_ratio': 1.785328012819913, 'min_atr_pct': 0.019073704013072304, 'max_atr_pct': 0.08323794827712971, 'use_breakout_trigger': False, 'risk_per_trade': 0.019967867432657223, 'rr_target': 3.8908351301018698, 'atr_stop_mult': 2.9923841610511177, 'max_bars_in_trade': 182}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:03,515] Trial 21 finished with value: -1000000.0 and parameters: {'ema_fast': 27, 'ema_slow': 149, 'atr_period': 16, 'volume_window': 48, 'swing_window': 18, 'slope_lookback': 8, 'pullback_min_pct': 0.009372101000488166, 'pullback_max_pct': 0.040823001830929816, 'max_close_above_fast_ema_pct': 0.0207202901485348, 'min_volume_ratio': 1.4571868582169587, 'min_atr_pct': 0.014493922238835489, 'max_atr_pct': 0.048969492465790236, 'use_breakout_trigger': False, 'risk_per_trade': 0.014649994219300931, 'rr_target': 1.029594135348093, 'atr_stop_mult': 2.1242553707084633, 'max_bars_in_trade': 129}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:07,162] Trial 22 finished with value: -1000000.0 and parameters: {'ema_fast': 39, 'ema_slow': 163, 'atr_period': 12, 'volume_window': 50, 'swing_window': 20, 'slope_lookback': 12, 'pullback_min_pct': 0.009991399525429824, 'pullback_max_pct': 0.03301695807975934, 'max_close_above_fast_ema_pct': 0.026009367146875836, 'min_volume_ratio': 1.4864544224285479, 'min_atr_pct': 0.013326435267907059, 'max_atr_pct': 0.10208551556834372, 'use_breakout_trigger': False, 'risk_per_trade': 0.01447553940097506, 'rr_target': 1.1019502566373374, 'atr_stop_mult': 2.3829430201981974, 'max_bars_in_trade': 16}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:10,877] Trial 23 finished with value: -1000000.0 and parameters: {'ema_fast': 32, 'ema_slow': 160, 'atr_period': 20, 'volume_window': 46, 'swing_window': 12, 'slope_lookback': 20, 'pullback_min_pct': 0.007839870303099142, 'pullback_max_pct': 0.03865616885128269, 'max_close_above_fast_ema_pct': 0.02267437766306624, 'min_volume_ratio': 1.3012724939117373, 'min_atr_pct': 0.015991554386154412, 'max_atr_pct': 0.021704716199676455, 'use_breakout_trigger': False, 'risk_per_trade': 0.01731947183736078, 'rr_target': 1.9671394931507993, 'atr_stop_mult': 2.1798412341341544, 'max_bars_in_trade': 128}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:14,650] Trial 24 finished with value: -1000000.0 and parameters: {'ema_fast': 18, 'ema_slow': 130, 'atr_period': 16, 'volume_window': 45, 'swing_window': 28, 'slope_lookback': 25, 'pullback_min_pct': 0.009101608126960424, 'pullback_max_pct': 0.04421623624074025, 'max_close_above_fast_ema_pct': 0.027201783127403414, 'min_volume_ratio': 1.355944331993856, 'min_atr_pct': 0.01165682167677101, 'max_atr_pct': 0.0926220875476085, 'use_breakout_trigger': False, 'risk_per_trade': 0.011054178476511765, 'rr_target': 3.3517506864770796, 'atr_stop_mult': 1.964381747720032, 'max_bars_in_trade': 69}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:18,211] Trial 25 finished with value: -1000000.0 and parameters: {'ema_fast': 27, 'ema_slow': 205, 'atr_period': 11, 'volume_window': 50, 'swing_window': 24, 'slope_lookback': 15, 'pullback_min_pct': 0.009227943991290769, 'pullback_max_pct': 0.015285107107716668, 'max_close_above_fast_ema_pct': 0.01903446091508579, 'min_volume_ratio': 1.2404376555422996, 'min_atr_pct': 0.014266101829820816, 'max_atr_pct': 0.07104407387485048, 'use_breakout_trigger': False, 'risk_per_trade': 0.013233335187753693, 'rr_target': 1.3345492797510539, 'atr_stop_mult': 2.7250914005815554, 'max_bars_in_trade': 109}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:21,764] Trial 26 finished with value: -1000000.0 and parameters: {'ema_fast': 42, 'ema_slow': 228, 'atr_period': 23, 'volume_window': 36, 'swing_window': 16, 'slope_lookback': 8, 'pullback_min_pct': 0.008205057025864975, 'pullback_max_pct': 0.050729021756679094, 'max_close_above_fast_ema_pct': 0.015185215540661467, 'min_volume_ratio': 1.0943289095588353, 'min_atr_pct': 0.017967960277018545, 'max_atr_pct': 0.1106557587666188, 'use_breakout_trigger': True, 'risk_per_trade': 0.004114651372875469, 'rr_target': 2.636305270251133, 'atr_stop_mult': 2.3332361631391483, 'max_bars_in_trade': 41}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:25,248] Trial 27 finished with value: -1000000.0 and parameters: {'ema_fast': 33, 'ema_slow': 120, 'atr_period': 15, 'volume_window': 45, 'swing_window': 7, 'slope_lookback': 27, 'pullback_min_pct': 0.005594299989844405, 'pullback_max_pct': 0.020671168070315812, 'max_close_above_fast_ema_pct': 0.024497568745331114, 'min_volume_ratio': 1.5502781097040355, 'min_atr_pct': 0.015487246404853876, 'max_atr_pct': 0.12687082418676793, 'use_breakout_trigger': False, 'risk_per_trade': 0.007431654848637406, 'rr_target': 2.9454366232843356, 'atr_stop_mult': 1.665230438360632, 'max_bars_in_trade': 144}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:28,797] Trial 28 finished with value: -1000000.0 and parameters: {'ema_fast': 25, 'ema_slow': 186, 'atr_period': 28, 'volume_window': 38, 'swing_window': 29, 'slope_lookback': 12, 'pullback_min_pct': 0.00632145516265825, 'pullback_max_pct': 0.031237218232466356, 'max_close_above_fast_ema_pct': 0.01062568983395887, 'min_volume_ratio': 1.7564433671755382, 'min_atr_pct': 0.011076298759260361, 'max_atr_pct': 0.07878695129761677, 'use_breakout_trigger': True, 'risk_per_trade': 0.010577825945691623, 'rr_target': 2.4512602373047376, 'atr_stop_mult': 2.253980265469018, 'max_bars_in_trade': 99}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:32,359] Trial 29 finished with value: -1000000.0 and parameters: {'ema_fast': 10, 'ema_slow': 248, 'atr_period': 18, 'volume_window': 42, 'swing_window': 22, 'slope_lookback': 24, 'pullback_min_pct': 0.0036917957951284113, 'pullback_max_pct': 0.013943003699727492, 'max_close_above_fast_ema_pct': 0.021348051808040364, 'min_volume_ratio': 1.0341704754728887, 'min_atr_pct': 0.008893897109422665, 'max_atr_pct': 0.05839541952581355, 'use_breakout_trigger': False, 'risk_per_trade': 0.014652467148669551, 'rr_target': 3.988711363828057, 'atr_stop_mult': 1.0523360679272904, 'max_bars_in_trade': 61}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:35,894] Trial 30 finished with value: -1000000.0 and parameters: {'ema_fast': 23, 'ema_slow': 156, 'atr_period': 19, 'volume_window': 21, 'swing_window': 8, 'slope_lookback': 20, 'pullback_min_pct': 0.007310242707420587, 'pullback_max_pct': 0.025432509732286668, 'max_close_above_fast_ema_pct': 0.017439612074514266, 'min_volume_ratio': 1.3936875380197007, 'min_atr_pct': 0.01348007266414433, 'max_atr_pct': 0.020573233324061357, 'use_breakout_trigger': False, 'risk_per_trade': 0.012184802495817734, 'rr_target': 3.267191747238518, 'atr_stop_mult': 2.5491371916256704, 'max_bars_in_trade': 187}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:39,448] Trial 31 finished with value: -1000000.0 and parameters: {'ema_fast': 18, 'ema_slow': 142, 'atr_period': 17, 'volume_window': 12, 'swing_window': 11, 'slope_lookback': 22, 'pullback_min_pct': 0.002825724458682448, 'pullback_max_pct': 0.020561303605854144, 'max_close_above_fast_ema_pct': 0.005034050333977259, 'min_volume_ratio': 0.8924089560951378, 'min_atr_pct': 0.015070113235216084, 'max_atr_pct': 0.06785738402754844, 'use_breakout_trigger': False, 'risk_per_trade': 0.005823342441590079, 'rr_target': 3.5004124876685117, 'atr_stop_mult': 1.0342393551554667, 'max_bars_in_trade': 35}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:43,262] Trial 32 finished with value: -1000000.0 and parameters: {'ema_fast': 29, 'ema_slow': 280, 'atr_period': 18, 'volume_window': 10, 'swing_window': 11, 'slope_lookback': 18, 'pullback_min_pct': 0.00465798134866914, 'pullback_max_pct': 0.018356595877085005, 'max_close_above_fast_ema_pct': 0.007446565559020194, 'min_volume_ratio': 0.9940515676734161, 'min_atr_pct': 0.005298395361861848, 'max_atr_pct': 0.04662072853292988, 'use_breakout_trigger': False, 'risk_per_trade': 0.005092039575185278, 'rr_target': 3.5958838033457585, 'atr_stop_mult': 0.9229418479738968, 'max_bars_in_trade': 62}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:46,995] Trial 33 finished with value: -1000000.0 and parameters: {'ema_fast': 17, 'ema_slow': 264, 'atr_period': 25, 'volume_window': 14, 'swing_window': 9, 'slope_lookback': 23, 'pullback_min_pct': 0.0036881127848646797, 'pullback_max_pct': 0.035716473215325506, 'max_close_above_fast_ema_pct': 0.008854917740547226, 'min_volume_ratio': 1.2294722128131557, 'min_atr_pct': 0.013323454492127901, 'max_atr_pct': 0.05572075407854798, 'use_breakout_trigger': False, 'risk_per_trade': 0.018389900259801126, 'rr_target': 2.9101358664937718, 'atr_stop_mult': 1.3876576898037993, 'max_bars_in_trade': 28}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:50,589] Trial 34 finished with value: -1000000.0 and parameters: {'ema_fast': 20, 'ema_slow': 274, 'atr_period': 11, 'volume_window': 15, 'swing_window': 5, 'slope_lookback': 17, 'pullback_min_pct': 0.008678562676527331, 'pullback_max_pct': 0.02588803306830861, 'max_close_above_fast_ema_pct': 0.0020984898534629898, 'min_volume_ratio': 1.340181876649016, 'min_atr_pct': 0.0029271507326794847, 'max_atr_pct': 0.030131957632607825, 'use_breakout_trigger': False, 'risk_per_trade': 0.01012734422390896, 'rr_target': 3.177517034491835, 'atr_stop_mult': 1.1827746758159616, 'max_bars_in_trade': 51}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:54,136] Trial 35 finished with value: -1000000.0 and parameters: {'ema_fast': 45, 'ema_slow': 238, 'atr_period': 20, 'volume_window': 18, 'swing_window': 16, 'slope_lookback': 20, 'pullback_min_pct': 0.004876462442243104, 'pullback_max_pct': 0.040402282805899484, 'max_close_above_fast_ema_pct': 0.013720179992835386, 'min_volume_ratio': 1.102463204484584, 'min_atr_pct': 0.012214343582495757, 'max_atr_pct': 0.10532300693351296, 'use_breakout_trigger': False, 'risk_per_trade': 0.008136059264836296, 'rr_target': 1.6793749533265045, 'atr_stop_mult': 2.8329765397759847, 'max_bars_in_trade': 10}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:30:57,654] Trial 36 finished with value: -1000000.0 and parameters: {'ema_fast': 24, 'ema_slow': 290, 'atr_period': 27, 'volume_window': 32, 'swing_window': 14, 'slope_lookback': 28, 'pullback_min_pct': 0.0023995556499214056, 'pullback_max_pct': 0.014188927433426668, 'max_close_above_fast_ema_pct': 0.02373367268826066, 'min_volume_ratio': 0.8136104929912847, 'min_atr_pct': 0.01722737850727442, 'max_atr_pct': 0.1203998733702681, 'use_breakout_trigger': True, 'risk_per_trade': 0.00640435267978073, 'rr_target': 3.4035083191080844, 'atr_stop_mult': 1.9763763488733086, 'max_bars_in_trade': 97}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:01,167] Trial 37 finished with value: -1000000.0 and parameters: {'ema_fast': 15, 'ema_slow': 174, 'atr_period': 16, 'volume_window': 23, 'swing_window': 19, 'slope_lookback': 7, 'pullback_min_pct': 0.0010393373209433574, 'pullback_max_pct': 0.02358114075867921, 'max_close_above_fast_ema_pct': 0.007166720680403312, 'min_volume_ratio': 1.4727756753166392, 'min_atr_pct': 0.016122366413481578, 'max_atr_pct': 0.14896670542741558, 'use_breakout_trigger': False, 'risk_per_trade': 0.0037273575924752374, 'rr_target': 3.797709183375781, 'atr_stop_mult': 0.8638706923273987, 'max_bars_in_trade': 76}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:04,757] Trial 38 finished with value: -1000000.0 and parameters: {'ema_fast': 34, 'ema_slow': 201, 'atr_period': 24, 'volume_window': 29, 'swing_window': 23, 'slope_lookback': 13, 'pullback_min_pct': 0.0037428224393129205, 'pullback_max_pct': 0.03178596945826941, 'max_close_above_fast_ema_pct': 0.027315142178755865, 'min_volume_ratio': 1.116825411019695, 'min_atr_pct': 0.014106526697899252, 'max_atr_pct': 0.08825370999616541, 'use_breakout_trigger': True, 'risk_per_trade': 0.013814119674034803, 'rr_target': 3.5740851932273725, 'atr_stop_mult': 1.5197490305343573, 'max_bars_in_trade': 234}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:08,412] Trial 39 finished with value: -1000000.0 and parameters: {'ema_fast': 29, 'ema_slow': 163, 'atr_period': 21, 'volume_window': 26, 'swing_window': 25, 'slope_lookback': 16, 'pullback_min_pct': 0.006051012722019278, 'pullback_max_pct': 0.019417305741873822, 'max_close_above_fast_ema_pct': 0.018047831767888347, 'min_volume_ratio': 0.9395474208754251, 'min_atr_pct': 0.010123781123305892, 'max_atr_pct': 0.0753398992582868, 'use_breakout_trigger': False, 'risk_per_trade': 0.01163528588121947, 'rr_target': 1.4357522874110018, 'atr_stop_mult': 1.7849296778547374, 'max_bars_in_trade': 146}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:11,997] Trial 40 finished with value: -1000000.0 and parameters: {'ema_fast': 38, 'ema_slow': 102, 'atr_period': 8, 'volume_window': 41, 'swing_window': 10, 'slope_lookback': 6, 'pullback_min_pct': 0.009504396485318681, 'pullback_max_pct': 0.012132226236924337, 'max_close_above_fast_ema_pct': 0.024870970692216356, 'min_volume_ratio': 1.207744629542183, 'min_atr_pct': 0.019945488227932753, 'max_atr_pct': 0.04163082263363621, 'use_breakout_trigger': True, 'risk_per_trade': 0.007754615569503498, 'rr_target': 2.264577852593745, 'atr_stop_mult': 1.2954586484287423, 'max_bars_in_trade': 119}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:15,774] Trial 41 finished with value: -1000000.0 and parameters: {'ema_fast': 13, 'ema_slow': 148, 'atr_period': 7, 'volume_window': 37, 'swing_window': 20, 'slope_lookback': 18, 'pullback_min_pct': 0.00837573947949164, 'pullback_max_pct': 0.05182761765358887, 'max_close_above_fast_ema_pct': 0.028152271931513467, 'min_volume_ratio': 1.8980076521074252, 'min_atr_pct': 0.005726018615573369, 'max_atr_pct': 0.1421851170301392, 'use_breakout_trigger': False, 'risk_per_trade': 0.018983983002961096, 'rr_target': 1.2394435417061367, 'atr_stop_mult': 2.8494338969332462, 'max_bars_in_trade': 211}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:19,254] Trial 42 finished with value: -1000000.0 and parameters: {'ema_fast': 10, 'ema_slow': 134, 'atr_period': 10, 'volume_window': 34, 'swing_window': 28, 'slope_lookback': 15, 'pullback_min_pct': 0.007274419485754429, 'pullback_max_pct': 0.05789381247170568, 'max_close_above_fast_ema_pct': 0.02313264908808385, 'min_volume_ratio': 1.841774573581361, 'min_atr_pct': 0.0030362959906986117, 'max_atr_pct': 0.11397850515955363, 'use_breakout_trigger': False, 'risk_per_trade': 0.016332610412694827, 'rr_target': 1.547069094124021, 'atr_stop_mult': 2.5228727405981277, 'max_bars_in_trade': 216}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:22,761] Trial 43 finished with value: -1000000.0 and parameters: {'ema_fast': 20, 'ema_slow': 124, 'atr_period': 14, 'volume_window': 43, 'swing_window': 25, 'slope_lookback': 21, 'pullback_min_pct': 0.007776001905775859, 'pullback_max_pct': 0.04958366195510849, 'max_close_above_fast_ema_pct': 0.02180781173230796, 'min_volume_ratio': 1.681973563494387, 'min_atr_pct': 0.004255012448285155, 'max_atr_pct': 0.13389419893576507, 'use_breakout_trigger': False, 'risk_per_trade': 0.0032329395363352087, 'rr_target': 2.5841128517505894, 'atr_stop_mult': 2.986263418211232, 'max_bars_in_trade': 296}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:26,339] Trial 44 finished with value: -1000000.0 and parameters: {'ema_fast': 22, 'ema_slow': 115, 'atr_period': 20, 'volume_window': 40, 'swing_window': 29, 'slope_lookback': 24, 'pullback_min_pct': 0.009641449415302678, 'pullback_max_pct': 0.0537262938633212, 'max_close_above_fast_ema_pct': 0.025541986775104684, 'min_volume_ratio': 1.9807880560401727, 'min_atr_pct': 0.006563385337709387, 'max_atr_pct': 0.0950172635039346, 'use_breakout_trigger': False, 'risk_per_trade': 0.008873725157171355, 'rr_target': 1.1601649370957337, 'atr_stop_mult': 1.0483862034656724, 'max_bars_in_trade': 258}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:29,877] Trial 45 finished with value: -1000000.0 and parameters: {'ema_fast': 13, 'ema_slow': 171, 'atr_period': 13, 'volume_window': 47, 'swing_window': 23, 'slope_lookback': 17, 'pullback_min_pct': 0.008847156973175145, 'pullback_max_pct': 0.045564203536061235, 'max_close_above_fast_ema_pct': 0.02696539323787365, 'min_volume_ratio': 1.5393698905423083, 'min_atr_pct': 0.0016483399261165758, 'max_atr_pct': 0.12634241063948506, 'use_breakout_trigger': True, 'risk_per_trade': 0.005486123312657973, 'rr_target': 2.8428430012831556, 'atr_stop_mult': 2.0227071261523535, 'max_bars_in_trade': 167}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:33,374] Trial 46 finished with value: -1000000.0 and parameters: {'ema_fast': 42, 'ema_slow': 146, 'atr_period': 22, 'volume_window': 44, 'swing_window': 18, 'slope_lookback': 23, 'pullback_min_pct': 0.008204555481155467, 'pullback_max_pct': 0.0562678657285374, 'max_close_above_fast_ema_pct': 0.02004726021373333, 'min_volume_ratio': 1.2749738874922067, 'min_atr_pct': 0.0023564534071489575, 'max_atr_pct': 0.08398912654994173, 'use_breakout_trigger': False, 'risk_per_trade': 0.015594460437175984, 'rr_target': 3.057941630889565, 'atr_stop_mult': 1.7722716467230415, 'max_bars_in_trade': 22}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:36,931] Trial 47 finished with value: -1000000.0 and parameters: {'ema_fast': 15, 'ema_slow': 185, 'atr_period': 17, 'volume_window': 11, 'swing_window': 26, 'slope_lookback': 19, 'pullback_min_pct': 0.004101848201074495, 'pullback_max_pct': 0.023667328955348125, 'max_close_above_fast_ema_pct': 0.02916300299454825, 'min_volume_ratio': 1.1561070423143702, 'min_atr_pct': 0.00477406905911765, 'max_atr_pct': 0.13994348332253462, 'use_breakout_trigger': True, 'risk_per_trade': 0.01232012470955678, 'rr_target': 1.8079975874904468, 'atr_stop_mult': 2.2250390181619006, 'max_bars_in_trade': 196}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:40,877] Trial 48 finished with value: -1000000.0 and parameters: {'ema_fast': 37, 'ema_slow': 110, 'atr_period': 28, 'volume_window': 40, 'swing_window': 21, 'slope_lookback': 26, 'pullback_min_pct': 0.008632739797681095, 'pullback_max_pct': 0.047494638627035075, 'max_close_above_fast_ema_pct': 0.024012024328080712, 'min_volume_ratio': 1.4082931698283372, 'min_atr_pct': 0.003643031011386335, 'max_atr_pct': 0.061160942510175176, 'use_breakout_trigger': False, 'risk_per_trade': 0.017966928341829343, 'rr_target': 3.770623811827222, 'atr_stop_mult': 1.8537599260952202, 'max_bars_in_trade': 227}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:44,417] Trial 49 finished with value: -1000000.0 and parameters: {'ema_fast': 47, 'ema_slow': 210, 'atr_period': 15, 'volume_window': 16, 'swing_window': 30, 'slope_lookback': 11, 'pullback_min_pct': 0.009198900714056261, 'pullback_max_pct': 0.04330834415795798, 'max_close_above_fast_ema_pct': 0.015018047457183952, 'min_volume_ratio': 1.6150459209019348, 'min_atr_pct': 0.012568126955395, 'max_atr_pct': 0.1169698702639074, 'use_breakout_trigger': False, 'risk_per_trade': 0.009983048562367045, 'rr_target': 2.0939325950293375, 'atr_stop_mult': 1.5105211248636057, 'max_bars_in_trade': 52}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:47,933] Trial 50 finished with value: -1000000.0 and parameters: {'ema_fast': 21, 'ema_slow': 297, 'atr_period': 9, 'volume_window': 19, 'swing_window': 26, 'slope_lookback': 14, 'pullback_min_pct': 0.00999512486521718, 'pullback_max_pct': 0.017248186234647828, 'max_close_above_fast_ema_pct': 0.01146551872408599, 'min_volume_ratio': 0.8955490775592466, 'min_atr_pct': 0.0089331607808404, 'max_atr_pct': 0.10542029666667796, 'use_breakout_trigger': True, 'risk_per_trade': 0.006657600458286777, 'rr_target': 1.3794483670727298, 'atr_stop_mult': 2.468680893698954, 'max_bars_in_trade': 151}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:51,589] Trial 51 finished with value: -1000000.0 and parameters: {'ema_fast': 41, 'ema_slow': 257, 'atr_period': 26, 'volume_window': 48, 'swing_window': 17, 'slope_lookback': 16, 'pullback_min_pct': 0.004492178830114859, 'pullback_max_pct': 0.03352295100873055, 'max_close_above_fast_ema_pct': 0.009674491875586685, 'min_volume_ratio': 1.341819291955691, 'min_atr_pct': 0.0010727880000118311, 'max_atr_pct': 0.031078696568166794, 'use_breakout_trigger': True, 'risk_per_trade': 0.009069494178797542, 'rr_target': 3.025301815208187, 'atr_stop_mult': 1.332722144057968, 'max_bars_in_trade': 93}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:55,620] Trial 52 finished with value: -1000000.0 and parameters: {'ema_fast': 44, 'ema_slow': 225, 'atr_period': 30, 'volume_window': 38, 'swing_window': 19, 'slope_lookback': 19, 'pullback_min_pct': 0.0031210383937310703, 'pullback_max_pct': 0.03824008712831631, 'max_close_above_fast_ema_pct': 0.01634303582344112, 'min_volume_ratio': 1.432055426720059, 'min_atr_pct': 0.0027013283018699225, 'max_atr_pct': 0.054423675713111984, 'use_breakout_trigger': True, 'risk_per_trade': 0.0071340449835798495, 'rr_target': 3.191862188420621, 'atr_stop_mult': 1.5981322662975361, 'max_bars_in_trade': 110}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:31:59,389] Trial 53 finished with value: -1000000.0 and parameters: {'ema_fast': 44, 'ema_slow': 272, 'atr_period': 26, 'volume_window': 42, 'swing_window': 14, 'slope_lookback': 21, 'pullback_min_pct': 0.00595120388813658, 'pullback_max_pct': 0.010315458398850268, 'max_close_above_fast_ema_pct': 0.005348023121460287, 'min_volume_ratio': 1.5032777081622952, 'min_atr_pct': 0.006154179924634767, 'max_atr_pct': 0.034900239915038336, 'use_breakout_trigger': True, 'risk_per_trade': 0.009928588786188594, 'rr_target': 2.7319548058690897, 'atr_stop_mult': 2.6609504672786977, 'max_bars_in_trade': 137}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:03,039] Trial 54 finished with value: -1000000.0 and parameters: {'ema_fast': 49, 'ema_slow': 234, 'atr_period': 28, 'volume_window': 34, 'swing_window': 22, 'slope_lookback': 9, 'pullback_min_pct': 0.005250787404852771, 'pullback_max_pct': 0.030302648348626955, 'max_close_above_fast_ema_pct': 0.026529589047457017, 'min_volume_ratio': 1.2824808390945068, 'min_atr_pct': 0.003954164090988397, 'max_atr_pct': 0.0450672191704562, 'use_breakout_trigger': True, 'risk_per_trade': 0.008700500076571235, 'rr_target': 2.5519360569963294, 'atr_stop_mult': 1.722184049126189, 'max_bars_in_trade': 156}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:06,626] Trial 55 finished with value: -1000000.0 and parameters: {'ema_fast': 47, 'ema_slow': 288, 'atr_period': 24, 'volume_window': 46, 'swing_window': 28, 'slope_lookback': 5, 'pullback_min_pct': 0.004260841198197544, 'pullback_max_pct': 0.026285867489806693, 'max_close_above_fast_ema_pct': 0.013239768254999375, 'min_volume_ratio': 1.7218477808778359, 'min_atr_pct': 0.002009068698271983, 'max_atr_pct': 0.0511623781995227, 'use_breakout_trigger': False, 'risk_per_trade': 0.01957617098318845, 'rr_target': 1.0026218493297425, 'atr_stop_mult': 1.8818429150358291, 'max_bars_in_trade': 179}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:10,133] Trial 56 finished with value: -1000000.0 and parameters: {'ema_fast': 35, 'ema_slow': 247, 'atr_period': 22, 'volume_window': 13, 'swing_window': 20, 'slope_lookback': 15, 'pullback_min_pct': 0.00686260074121652, 'pullback_max_pct': 0.02184680618365922, 'max_close_above_fast_ema_pct': 0.025127245962447194, 'min_volume_ratio': 1.3557304585061556, 'min_atr_pct': 0.00744367848681589, 'max_atr_pct': 0.07587370875222535, 'use_breakout_trigger': True, 'risk_per_trade': 0.004685939341054343, 'rr_target': 2.351953908296731, 'atr_stop_mult': 2.2922805184162796, 'max_bars_in_trade': 118}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:13,752] Trial 57 finished with value: -1000000.0 and parameters: {'ema_fast': 39, 'ema_slow': 218, 'atr_period': 19, 'volume_window': 50, 'swing_window': 16, 'slope_lookback': 21, 'pullback_min_pct': 0.0033873447164858234, 'pullback_max_pct': 0.01236336615187273, 'max_close_above_fast_ema_pct': 0.018653961692131963, 'min_volume_ratio': 1.186712892219432, 'min_atr_pct': 0.014819933881732323, 'max_atr_pct': 0.06577751681855429, 'use_breakout_trigger': False, 'risk_per_trade': 0.015487816816976224, 'rr_target': 3.24826858913016, 'atr_stop_mult': 1.1492594601518, 'max_bars_in_trade': 249}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:17,292] Trial 58 finished with value: -1000000.0 and parameters: {'ema_fast': 30, 'ema_slow': 261, 'atr_period': 17, 'volume_window': 44, 'swing_window': 23, 'slope_lookback': 13, 'pullback_min_pct': 0.0021887172601685627, 'pullback_max_pct': 0.04277555335187012, 'max_close_above_fast_ema_pct': 0.02832921987257089, 'min_volume_ratio': 1.0324502027550269, 'min_atr_pct': 0.0033589136652149333, 'max_atr_pct': 0.03677101432203122, 'use_breakout_trigger': True, 'risk_per_trade': 0.013484628902237339, 'rr_target': 2.9704052446339126, 'atr_stop_mult': 2.107166674899677, 'max_bars_in_trade': 79}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:20,723] Trial 59 finished with value: -1000000.0 and parameters: {'ema_fast': 26, 'ema_slow': 154, 'atr_period': 29, 'volume_window': 38, 'swing_window': 21, 'slope_lookback': 30, 'pullback_min_pct': 0.005249645696359225, 'pullback_max_pct': 0.027466267417837014, 'max_close_above_fast_ema_pct': 0.022350970367614433, 'min_volume_ratio': 1.5805404132361942, 'min_atr_pct': 0.010880297316333568, 'max_atr_pct': 0.14770587665925458, 'use_breakout_trigger': False, 'risk_per_trade': 0.011391277803630103, 'rr_target': 2.817126259246807, 'atr_stop_mult': 1.5038795219551655, 'max_bars_in_trade': 35}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:24,978] A new study created in memory with name: no-name-c412e58e-090e-4875-a939-d0c6aef705be
#   IS  | return=0.00% | dd=0.00% | trades=0 | pf=0.00
#   OOS | return=0.00% | dd=0.00% | trades=0 | pf=0.00
#
# WFA window 2/7 | TRAIN: 2025-06-02 -> 2025-10-02 | TEST: 2025-10-02 -> 2025-11-02
# [I 2026-04-14 16:32:28,543] Trial 0 finished with value: -1000000.0 and parameters: {'ema_fast': 21, 'ema_slow': 130, 'atr_period': 18, 'volume_window': 42, 'swing_window': 8, 'slope_lookback': 18, 'pullback_min_pct': 0.0010966403635377375, 'pullback_max_pct': 0.04522664222692626, 'max_close_above_fast_ema_pct': 0.004993755755412123, 'min_volume_ratio': 1.7074384858043454, 'min_atr_pct': 0.01935962760275927, 'max_atr_pct': 0.02995273235599389, 'use_breakout_trigger': False, 'risk_per_trade': 0.009499337464308887, 'rr_target': 2.3713480347583635, 'atr_stop_mult': 2.0934541113439717, 'max_bars_in_trade': 143}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:32,079] Trial 1 finished with value: -1000000.0 and parameters: {'ema_fast': 20, 'ema_slow': 281, 'atr_period': 28, 'volume_window': 14, 'swing_window': 30, 'slope_lookback': 23, 'pullback_min_pct': 0.00315496535681502, 'pullback_max_pct': 0.04607975112995446, 'max_close_above_fast_ema_pct': 0.028870178529762112, 'min_volume_ratio': 0.8868854141937922, 'min_atr_pct': 0.00978295848008845, 'max_atr_pct': 0.07244118136741193, 'use_breakout_trigger': True, 'risk_per_trade': 0.01004858964781061, 'rr_target': 1.4540404946616574, 'atr_stop_mult': 1.4208236884379946, 'max_bars_in_trade': 29}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:35,667] Trial 2 finished with value: -1000000.0 and parameters: {'ema_fast': 29, 'ema_slow': 216, 'atr_period': 20, 'volume_window': 37, 'swing_window': 21, 'slope_lookback': 21, 'pullback_min_pct': 0.0021444416545526885, 'pullback_max_pct': 0.032482915587935375, 'max_close_above_fast_ema_pct': 0.02425290747683371, 'min_volume_ratio': 1.7086912857558583, 'min_atr_pct': 0.007663650959941835, 'max_atr_pct': 0.1461833936028283, 'use_breakout_trigger': True, 'risk_per_trade': 0.008324245707216337, 'rr_target': 1.3861555469548785, 'atr_stop_mult': 2.621627130803142, 'max_bars_in_trade': 200}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:39,113] Trial 3 finished with value: -1000000.0 and parameters: {'ema_fast': 17, 'ema_slow': 217, 'atr_period': 16, 'volume_window': 23, 'swing_window': 13, 'slope_lookback': 29, 'pullback_min_pct': 0.007322329557521303, 'pullback_max_pct': 0.05122754768757536, 'max_close_above_fast_ema_pct': 0.014628775248035492, 'min_volume_ratio': 0.8600572712526684, 'min_atr_pct': 0.014847167729529858, 'max_atr_pct': 0.0815783570498467, 'use_breakout_trigger': True, 'risk_per_trade': 0.007626541312967236, 'rr_target': 2.5409049269863306, 'atr_stop_mult': 2.9001285801485306, 'max_bars_in_trade': 174}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:42,728] Trial 4 finished with value: -1000000.0 and parameters: {'ema_fast': 30, 'ema_slow': 168, 'atr_period': 19, 'volume_window': 45, 'swing_window': 9, 'slope_lookback': 25, 'pullback_min_pct': 0.00829752099358804, 'pullback_max_pct': 0.032364530951950035, 'max_close_above_fast_ema_pct': 0.010247448676150649, 'min_volume_ratio': 0.8550818239157911, 'min_atr_pct': 0.006006491792062109, 'max_atr_pct': 0.09082750796054584, 'use_breakout_trigger': False, 'risk_per_trade': 0.007928950324768029, 'rr_target': 2.52076481274223, 'atr_stop_mult': 1.2171038819563726, 'max_bars_in_trade': 132}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:46,238] Trial 5 finished with value: -1000000.0 and parameters: {'ema_fast': 10, 'ema_slow': 106, 'atr_period': 22, 'volume_window': 31, 'swing_window': 19, 'slope_lookback': 9, 'pullback_min_pct': 0.008354006659962755, 'pullback_max_pct': 0.03082506056063191, 'max_close_above_fast_ema_pct': 0.007919867907849938, 'min_volume_ratio': 1.5702876530861913, 'min_atr_pct': 0.014875368806893306, 'max_atr_pct': 0.07182285334631497, 'use_breakout_trigger': True, 'risk_per_trade': 0.009796942239054314, 'rr_target': 3.942024920421154, 'atr_stop_mult': 0.8612996000437705, 'max_bars_in_trade': 90}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:49,706] Trial 6 finished with value: -1000000.0 and parameters: {'ema_fast': 41, 'ema_slow': 265, 'atr_period': 30, 'volume_window': 49, 'swing_window': 20, 'slope_lookback': 14, 'pullback_min_pct': 0.00622082160222171, 'pullback_max_pct': 0.017020065031266737, 'max_close_above_fast_ema_pct': 0.017013031186262975, 'min_volume_ratio': 1.460422749886254, 'min_atr_pct': 0.009016317596655932, 'max_atr_pct': 0.0834653352659593, 'use_breakout_trigger': True, 'risk_per_trade': 0.0060172060411345435, 'rr_target': 2.4669906721188717, 'atr_stop_mult': 2.662440500647345, 'max_bars_in_trade': 99}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:53,492] Trial 7 finished with value: -1000000.0 and parameters: {'ema_fast': 33, 'ema_slow': 102, 'atr_period': 14, 'volume_window': 50, 'swing_window': 19, 'slope_lookback': 6, 'pullback_min_pct': 0.008519024648495202, 'pullback_max_pct': 0.010335394097535807, 'max_close_above_fast_ema_pct': 0.02494801888147967, 'min_volume_ratio': 1.8401903646253808, 'min_atr_pct': 0.016858091320137963, 'max_atr_pct': 0.10992130460517424, 'use_breakout_trigger': True, 'risk_per_trade': 0.01890341730095417, 'rr_target': 3.3108600036717943, 'atr_stop_mult': 2.0788236931522777, 'max_bars_in_trade': 286}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:32:56,930] Trial 8 finished with value: -1000000.0 and parameters: {'ema_fast': 16, 'ema_slow': 251, 'atr_period': 14, 'volume_window': 31, 'swing_window': 13, 'slope_lookback': 19, 'pullback_min_pct': 0.0049579442491839475, 'pullback_max_pct': 0.013776326044522953, 'max_close_above_fast_ema_pct': 0.021157490196599828, 'min_volume_ratio': 1.5065504403980547, 'min_atr_pct': 0.015471870760506153, 'max_atr_pct': 0.05328972826602932, 'use_breakout_trigger': False, 'risk_per_trade': 0.0055205431036952175, 'rr_target': 1.710832301691795, 'atr_stop_mult': 1.805258764221145, 'max_bars_in_trade': 264}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:33:01,047] Trial 9 finished with value: -1000000.0 and parameters: {'ema_fast': 49, 'ema_slow': 222, 'atr_period': 26, 'volume_window': 25, 'swing_window': 20, 'slope_lookback': 22, 'pullback_min_pct': 0.009804937129021356, 'pullback_max_pct': 0.014562305854225457, 'max_close_above_fast_ema_pct': 0.024674608736888648, 'min_volume_ratio': 1.3605271107762373, 'min_atr_pct': 0.0011323760539754403, 'max_atr_pct': 0.04569198880826923, 'use_breakout_trigger': False, 'risk_per_trade': 0.007921944526109377, 'rr_target': 1.2786943564269793, 'atr_stop_mult': 2.952966173040817, 'max_bars_in_trade': 89}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:33:06,320] Trial 10 finished with value: -1000000.0 and parameters: {'ema_fast': 24, 'ema_slow': 157, 'atr_period': 11, 'volume_window': 40, 'swing_window': 5, 'slope_lookback': 15, 'pullback_min_pct': 0.001018003206777699, 'pullback_max_pct': 0.05745104866762084, 'max_close_above_fast_ema_pct': 0.002252578142470169, 'min_volume_ratio': 1.9704751645500012, 'min_atr_pct': 0.019489016981548368, 'max_atr_pct': 0.021771067581366363, 'use_breakout_trigger': False, 'risk_per_trade': 0.015350544630228025, 'rr_target': 2.0704779517561698, 'atr_stop_mult': 2.2418421487262163, 'max_bars_in_trade': 224}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:33:10,859] Trial 11 finished with value: -1000000.0 and parameters: {'ema_fast': 20, 'ema_slow': 296, 'atr_period': 7, 'volume_window': 11, 'swing_window': 30, 'slope_lookback': 25, 'pullback_min_pct': 0.0033039216550209993, 'pullback_max_pct': 0.04454007207289636, 'max_close_above_fast_ema_pct': 0.029556892590466507, 'min_volume_ratio': 1.1490523820857026, 'min_atr_pct': 0.011435364939946954, 'max_atr_pct': 0.022377214210245182, 'use_breakout_trigger': False, 'risk_per_trade': 0.013426593090014814, 'rr_target': 1.0262475527396722, 'atr_stop_mult': 1.6538413702382269, 'max_bars_in_trade': 28}. Best is trial 0 with value: -1000000.0.
# ...
# [I 2026-04-14 16:34:41,400] Trial 35 finished with value: -1000000.0 and parameters: {'ema_fast': 17, 'ema_slow': 115, 'atr_period': 14, 'volume_window': 31, 'swing_window': 18, 'slope_lookback': 8, 'pullback_min_pct': 0.007945371674735626, 'pullback_max_pct': 0.05409700993701905, 'max_close_above_fast_ema_pct': 0.008587254685897813, 'min_volume_ratio': 0.8907661203053551, 'min_atr_pct': 0.00835599683352045, 'max_atr_pct': 0.11275715820023187, 'use_breakout_trigger': True, 'risk_per_trade': 0.0044051980323526006, 'rr_target': 2.65798205130326, 'atr_stop_mult': 1.0418716307936808, 'max_bars_in_trade': 285}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:34:44,855] Trial 36 finished with value: -1000000.0 and parameters: {'ema_fast': 25, 'ema_slow': 258, 'atr_period': 21, 'volume_window': 14, 'swing_window': 12, 'slope_lookback': 20, 'pullback_min_pct': 0.008116421875912418, 'pullback_max_pct': 0.04692627218677427, 'max_close_above_fast_ema_pct': 0.025385208916300358, 'min_volume_ratio': 1.4667088135467345, 'min_atr_pct': 0.011359711812149354, 'max_atr_pct': 0.07672668890449522, 'use_breakout_trigger': False, 'risk_per_trade': 0.006054779284107089, 'rr_target': 2.369244421107811, 'atr_stop_mult': 2.0910383576359304, 'max_bars_in_trade': 209}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:34:48,304] Trial 37 finished with value: -1000000.0 and parameters: {'ema_fast': 21, 'ema_slow': 229, 'atr_period': 29, 'volume_window': 33, 'swing_window': 15, 'slope_lookback': 22, 'pullback_min_pct': 0.002324780841886741, 'pullback_max_pct': 0.031939726883786206, 'max_close_above_fast_ema_pct': 0.01698491011847054, 'min_volume_ratio': 1.0540027264246374, 'min_atr_pct': 0.015774605105743345, 'max_atr_pct': 0.054564900617515344, 'use_breakout_trigger': True, 'risk_per_trade': 0.008854254969218815, 'rr_target': 3.375826526370255, 'atr_stop_mult': 1.3024220766263808, 'max_bars_in_trade': 73}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:34:51,778] Trial 38 finished with value: -1000000.0 and parameters: {'ema_fast': 36, 'ema_slow': 183, 'atr_period': 15, 'volume_window': 48, 'swing_window': 19, 'slope_lookback': 24, 'pullback_min_pct': 0.001497270459443889, 'pullback_max_pct': 0.040051893776900466, 'max_close_above_fast_ema_pct': 0.014682480329380732, 'min_volume_ratio': 1.5923020433940938, 'min_atr_pct': 0.014108652598162649, 'max_atr_pct': 0.08818377709977943, 'use_breakout_trigger': False, 'risk_per_trade': 0.010002156089250652, 'rr_target': 2.037155401145627, 'atr_stop_mult': 2.6565151235097013, 'max_bars_in_trade': 99}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:34:55,403] Trial 39 finished with value: -1000000.0 and parameters: {'ema_fast': 28, 'ema_slow': 143, 'atr_period': 19, 'volume_window': 13, 'swing_window': 29, 'slope_lookback': 19, 'pullback_min_pct': 0.005720268355456357, 'pullback_max_pct': 0.019814066460822392, 'max_close_above_fast_ema_pct': 0.00599806740464449, 'min_volume_ratio': 1.022915009375517, 'min_atr_pct': 0.010168604193132147, 'max_atr_pct': 0.057573224889810745, 'use_breakout_trigger': True, 'risk_per_trade': 0.013008623413379307, 'rr_target': 2.4609565601437207, 'atr_stop_mult': 2.2208131995193647, 'max_bars_in_trade': 34}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:34:58,817] Trial 40 finished with value: -1000000.0 and parameters: {'ema_fast': 43, 'ema_slow': 290, 'atr_period': 10, 'volume_window': 18, 'swing_window': 25, 'slope_lookback': 5, 'pullback_min_pct': 0.0034084608879948386, 'pullback_max_pct': 0.051843785178199556, 'max_close_above_fast_ema_pct': 0.0036544155873563296, 'min_volume_ratio': 1.3479949998151755, 'min_atr_pct': 0.018526654639016333, 'max_atr_pct': 0.04320746883751885, 'use_breakout_trigger': False, 'risk_per_trade': 0.01438833580190518, 'rr_target': 1.259437943843921, 'atr_stop_mult': 0.8074391395451936, 'max_bars_in_trade': 234}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:02,308] Trial 41 finished with value: -1000000.0 and parameters: {'ema_fast': 31, 'ema_slow': 108, 'atr_period': 17, 'volume_window': 50, 'swing_window': 9, 'slope_lookback': 26, 'pullback_min_pct': 0.008811313735881218, 'pullback_max_pct': 0.03076197383825225, 'max_close_above_fast_ema_pct': 0.01105518803644864, 'min_volume_ratio': 0.9013013211372919, 'min_atr_pct': 0.006325616724149493, 'max_atr_pct': 0.02579688818250267, 'use_breakout_trigger': False, 'risk_per_trade': 0.008324117322506076, 'rr_target': 2.5903991686846823, 'atr_stop_mult': 1.1702986383490153, 'max_bars_in_trade': 127}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:05,726] Trial 42 finished with value: -1000000.0 and parameters: {'ema_fast': 30, 'ema_slow': 169, 'atr_period': 22, 'volume_window': 43, 'swing_window': 6, 'slope_lookback': 28, 'pullback_min_pct': 0.009835247173698457, 'pullback_max_pct': 0.033620054710932885, 'max_close_above_fast_ema_pct': 0.0076498272420546095, 'min_volume_ratio': 0.856533063053967, 'min_atr_pct': 0.005835814977100375, 'max_atr_pct': 0.07250333755768507, 'use_breakout_trigger': False, 'risk_per_trade': 0.007483466153636321, 'rr_target': 2.3998850656478683, 'atr_stop_mult': 1.3883153696384456, 'max_bars_in_trade': 148}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:09,328] Trial 43 finished with value: -1000000.0 and parameters: {'ema_fast': 23, 'ema_slow': 165, 'atr_period': 20, 'volume_window': 46, 'swing_window': 10, 'slope_lookback': 23, 'pullback_min_pct': 0.007637168787910159, 'pullback_max_pct': 0.04186351871078955, 'max_close_above_fast_ema_pct': 0.009825609914506208, 'min_volume_ratio': 1.1366543875829516, 'min_atr_pct': 0.009289107974989332, 'max_atr_pct': 0.13009480833341266, 'use_breakout_trigger': False, 'risk_per_trade': 0.005404509653545617, 'rr_target': 3.225490809684751, 'atr_stop_mult': 1.5502421018938342, 'max_bars_in_trade': 179}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:12,735] Trial 44 finished with value: -1000000.0 and parameters: {'ema_fast': 36, 'ema_slow': 195, 'atr_period': 13, 'volume_window': 38, 'swing_window': 12, 'slope_lookback': 25, 'pullback_min_pct': 0.008958267703857976, 'pullback_max_pct': 0.045028660868814796, 'max_close_above_fast_ema_pct': 0.013457485394082007, 'min_volume_ratio': 0.9184929701881909, 'min_atr_pct': 0.016102241263954327, 'max_atr_pct': 0.0806483619022887, 'use_breakout_trigger': False, 'risk_per_trade': 0.011847718651437163, 'rr_target': 2.1591913293501, 'atr_stop_mult': 1.749469847943232, 'max_bars_in_trade': 159}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:16,169] Trial 45 finished with value: -1000000.0 and parameters: {'ema_fast': 39, 'ema_slow': 146, 'atr_period': 17, 'volume_window': 10, 'swing_window': 8, 'slope_lookback': 21, 'pullback_min_pct': 0.00939563228230364, 'pullback_max_pct': 0.057338293140335866, 'max_close_above_fast_ema_pct': 0.029993336999837715, 'min_volume_ratio': 1.0105719838719052, 'min_atr_pct': 0.011458601226351756, 'max_atr_pct': 0.046684950079512545, 'use_breakout_trigger': False, 'risk_per_trade': 0.019156574834008618, 'rr_target': 2.8911458501147473, 'atr_stop_mult': 0.9876103043209898, 'max_bars_in_trade': 12}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:19,598] Trial 46 finished with value: -1000000.0 and parameters: {'ema_fast': 10, 'ema_slow': 247, 'atr_period': 15, 'volume_window': 39, 'swing_window': 6, 'slope_lookback': 18, 'pullback_min_pct': 0.007662015860642966, 'pullback_max_pct': 0.03758044020109607, 'max_close_above_fast_ema_pct': 0.016473100664938366, 'min_volume_ratio': 1.097362134727227, 'min_atr_pct': 0.008058848998185354, 'max_atr_pct': 0.12246618386521868, 'use_breakout_trigger': False, 'risk_per_trade': 0.0065723181732380105, 'rr_target': 1.6452552825950073, 'atr_stop_mult': 1.1291957030504194, 'max_bars_in_trade': 136}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:23,153] Trial 47 finished with value: -1000000.0 and parameters: {'ema_fast': 20, 'ema_slow': 118, 'atr_period': 23, 'volume_window': 42, 'swing_window': 20, 'slope_lookback': 29, 'pullback_min_pct': 0.008672854147863882, 'pullback_max_pct': 0.025234288000966963, 'max_close_above_fast_ema_pct': 0.018114607996493285, 'min_volume_ratio': 1.8165680017890735, 'min_atr_pct': 0.004614590973604272, 'max_atr_pct': 0.029443312253639997, 'use_breakout_trigger': True, 'risk_per_trade': 0.009225393505762668, 'rr_target': 1.878941098585757, 'atr_stop_mult': 2.857504650320341, 'max_bars_in_trade': 101}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:26,474] Trial 48 finished with value: -1000000.0 and parameters: {'ema_fast': 32, 'ema_slow': 159, 'atr_period': 26, 'volume_window': 24, 'swing_window': 29, 'slope_lookback': 15, 'pullback_min_pct': 0.0030815411070528073, 'pullback_max_pct': 0.027746807684130525, 'max_close_above_fast_ema_pct': 0.02640717621213497, 'min_volume_ratio': 1.63001599112841, 'min_atr_pct': 0.0017687907594635954, 'max_atr_pct': 0.10969974238262313, 'use_breakout_trigger': False, 'risk_per_trade': 0.010647481010158909, 'rr_target': 2.6403430240979224, 'atr_stop_mult': 1.2540045757693676, 'max_bars_in_trade': 172}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:29,979] Trial 49 finished with value: -1000000.0 and parameters: {'ema_fast': 27, 'ema_slow': 264, 'atr_period': 30, 'volume_window': 29, 'swing_window': 14, 'slope_lookback': 22, 'pullback_min_pct': 0.0010156325822229032, 'pullback_max_pct': 0.041324344177875, 'max_close_above_fast_ema_pct': 0.012585180682649707, 'min_volume_ratio': 1.7655352157331519, 'min_atr_pct': 0.019148003654918082, 'max_atr_pct': 0.0938598715928721, 'use_breakout_trigger': True, 'risk_per_trade': 0.007875878735607945, 'rr_target': 1.365424519856649, 'atr_stop_mult': 2.9990429858690746, 'max_bars_in_trade': 85}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:33,348] Trial 50 finished with value: -1000000.0 and parameters: {'ema_fast': 47, 'ema_slow': 135, 'atr_period': 21, 'volume_window': 45, 'swing_window': 9, 'slope_lookback': 24, 'pullback_min_pct': 0.0014242581051931592, 'pullback_max_pct': 0.010738089399565273, 'max_close_above_fast_ema_pct': 0.003644954854537256, 'min_volume_ratio': 1.185466081893827, 'min_atr_pct': 0.016716882815027225, 'max_atr_pct': 0.06866544182438723, 'use_breakout_trigger': True, 'risk_per_trade': 0.017346339324461772, 'rr_target': 1.11205485928825, 'atr_stop_mult': 1.451677736949986, 'max_bars_in_trade': 235}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:36,644] Trial 51 finished with value: -1000000.0 and parameters: {'ema_fast': 11, 'ema_slow': 102, 'atr_period': 18, 'volume_window': 35, 'swing_window': 18, 'slope_lookback': 11, 'pullback_min_pct': 0.00832169942630124, 'pullback_max_pct': 0.030384023739528983, 'max_close_above_fast_ema_pct': 0.02852526045726233, 'min_volume_ratio': 1.4746568630258559, 'min_atr_pct': 0.014146598012177982, 'max_atr_pct': 0.08266309455785284, 'use_breakout_trigger': True, 'risk_per_trade': 0.009599431314019044, 'rr_target': 3.96495485332486, 'atr_stop_mult': 0.9352663215837448, 'max_bars_in_trade': 42}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:40,123] Trial 52 finished with value: -1000000.0 and parameters: {'ema_fast': 14, 'ema_slow': 100, 'atr_period': 19, 'volume_window': 32, 'swing_window': 21, 'slope_lookback': 9, 'pullback_min_pct': 0.002292157300066641, 'pullback_max_pct': 0.03683463562890951, 'max_close_above_fast_ema_pct': 0.008609407389725297, 'min_volume_ratio': 1.5556640498176988, 'min_atr_pct': 0.019973539469115786, 'max_atr_pct': 0.07254897689415905, 'use_breakout_trigger': True, 'risk_per_trade': 0.010686168439116277, 'rr_target': 3.7300466294601233, 'atr_stop_mult': 1.5891056096857512, 'max_bars_in_trade': 113}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:43,817] Trial 53 finished with value: -1000000.0 and parameters: {'ema_fast': 24, 'ema_slow': 116, 'atr_period': 27, 'volume_window': 28, 'swing_window': 25, 'slope_lookback': 20, 'pullback_min_pct': 0.009394425938763391, 'pullback_max_pct': 0.03332399799904029, 'max_close_above_fast_ema_pct': 0.005818988514513357, 'min_volume_ratio': 1.4091158507546317, 'min_atr_pct': 0.01772996401336853, 'max_atr_pct': 0.05903470664907754, 'use_breakout_trigger': True, 'risk_per_trade': 0.008273447621203031, 'rr_target': 3.1009970196650976, 'atr_stop_mult': 1.8715859167887765, 'max_bars_in_trade': 131}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:47,381] Trial 54 finished with value: -1000000.0 and parameters: {'ema_fast': 17, 'ema_slow': 126, 'atr_period': 23, 'volume_window': 40, 'swing_window': 23, 'slope_lookback': 7, 'pullback_min_pct': 0.0062851780454073, 'pullback_max_pct': 0.049436427943554684, 'max_close_above_fast_ema_pct': 0.007537761793277467, 'min_volume_ratio': 1.7143849349534643, 'min_atr_pct': 0.011643555024653097, 'max_atr_pct': 0.06667356265827028, 'use_breakout_trigger': True, 'risk_per_trade': 0.010077645378256426, 'rr_target': 3.403147840938333, 'atr_stop_mult': 0.8083298001198337, 'max_bars_in_trade': 60}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:51,345] Trial 55 finished with value: -1000000.0 and parameters: {'ema_fast': 22, 'ema_slow': 185, 'atr_period': 20, 'volume_window': 36, 'swing_window': 17, 'slope_lookback': 19, 'pullback_min_pct': 0.003952046352698504, 'pullback_max_pct': 0.0220224829684535, 'max_close_above_fast_ema_pct': 0.009782519866261111, 'min_volume_ratio': 1.6349821220780865, 'min_atr_pct': 0.007190626968731092, 'max_atr_pct': 0.05067007176904398, 'use_breakout_trigger': True, 'risk_per_trade': 0.012649684108207139, 'rr_target': 3.541359004736787, 'atr_stop_mult': 1.2239124532164452, 'max_bars_in_trade': 186}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:54,863] Trial 56 finished with value: -1000000.0 and parameters: {'ema_fast': 14, 'ema_slow': 220, 'atr_period': 22, 'volume_window': 25, 'swing_window': 16, 'slope_lookback': 22, 'pullback_min_pct': 0.007634338216832822, 'pullback_max_pct': 0.02894550052577887, 'max_close_above_fast_ema_pct': 0.021011180426122763, 'min_volume_ratio': 1.8569323679873904, 'min_atr_pct': 0.008720168922215209, 'max_atr_pct': 0.041707375773704744, 'use_breakout_trigger': False, 'risk_per_trade': 0.006861989663062222, 'rr_target': 1.410841213915952, 'atr_stop_mult': 1.3484457387068698, 'max_bars_in_trade': 70}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:35:58,830] Trial 57 finished with value: -1000000.0 and parameters: {'ema_fast': 18, 'ema_slow': 138, 'atr_period': 7, 'volume_window': 44, 'swing_window': 5, 'slope_lookback': 26, 'pullback_min_pct': 0.00460280053125087, 'pullback_max_pct': 0.0345599631200645, 'max_close_above_fast_ema_pct': 0.023883991295596322, 'min_volume_ratio': 1.281702480339444, 'min_atr_pct': 0.01067223033413155, 'max_atr_pct': 0.13617200477517946, 'use_breakout_trigger': True, 'risk_per_trade': 0.0057968537426614924, 'rr_target': 1.5799022330430206, 'atr_stop_mult': 1.049581851293712, 'max_bars_in_trade': 23}. Best is trial 0 with value: -1000000.0.
# [I 2026-04-14 16:36:02,393] Trial 58 finished with value: -1000000.0 and parameters: {'ema_fast': 10, 'ema_slow': 128, 'atr_period': 17, 'volume_window': 12, 'swing_window': 19, 'slope_lookback': 16, 'pullback_min_pct': 0.006568343179445211, 'pullback_max_pct': 0.04427570753057195, 'max_close_above_fast_ema_pct': 0.002571809662016116, 'min_volume_ratio': 1.524228361654801, 'min_atr_pct': 0.00980212738198008, 'max_atr_pct': 0.08771784100556071, 'use_breakout_trigger': False, 'risk_per_trade': 0.011457036007303713, 'rr_target': 1.7751187745379973, 'atr_stop_mult': 2.0377748829679394, 'max_bars_in_trade': 201}. Best is trial 0 with value: -1000000.0.

# %% [markdown]
# # график stitched OOS equity

# %%
eq = wfa_result["stitched_oos_equity"]

if not eq.empty:
    plt.figure(figsize=(12, 5))
    plt.plot(eq.index, eq["equity"])
    plt.title("Walk-Forward Stitched OOS Equity")
    plt.xlabel("Date")
    plt.ylabel("Equity")
    plt.grid(True)
    plt.show()

# %% [markdown]
# # просмотр OOS результатов по окнам

# %%
cols = [
    "window_id",
    "train_start", "train_end",
    "test_start", "test_end",
    "is_return_pct", "oos_return_pct",
    "is_pf", "oos_pf",
    "oos_n_trades"
]

wfa_result["windows_df"][cols]
# Out:
#    window_id train_start  train_end test_start   test_end  is_return_pct  \
# 0          1  2025-09-18 2026-01-18 2026-01-18 2026-02-18       1.212041
# 1          2  2025-10-18 2026-02-18 2026-02-18 2026-03-18      -3.104071
#
#    oos_return_pct     is_pf    oos_pf  oos_n_trades
# 0       -0.159645  1.668992  0.190433             2
# 1        0.755740  0.000000  1.796975             4

# %% [markdown]
# # Просмотр всех OOS сделок

# %%
wfa_result["all_oos_trades_df"].head(20)
# Out:
#            entry_time           exit_time  size      price_in     price_out  \
# 0 2026-02-06 19:55:00 2026-02-06 21:30:00   0.0  70788.504870  70788.504870
# 1 2026-02-07 01:50:00 2026-02-07 03:25:00   0.0  70548.096798  70548.096798
# 2 2026-02-20 17:50:00 2026-02-21 08:55:00   0.0  67533.944088  67533.944088
# 3 2026-02-28 21:40:00 2026-03-01 12:45:00   0.0  66833.734074  66833.734074
# 4 2026-03-03 19:40:00 2026-03-04 03:35:00   0.0  68614.730202  68614.730202
# 5 2026-03-04 15:05:00 2026-03-04 19:25:00   0.0  71684.974128  71684.974128
#
#     pnl_gross     pnl_net  barlen  window_id
# 0  -17.286222  -19.719836      19          1
# 1    8.022768    3.755299      19          1
# 2   43.880540   38.832901     181          2
# 3  -16.746823  -19.256909     181          2
# 4  -72.010701  -75.569134      95          2
# 5  135.588148  131.567108      52          2
